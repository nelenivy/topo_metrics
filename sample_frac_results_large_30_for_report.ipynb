# %%
print(corr_df)
# Out:
#      sample_fraction                            metric  correlation
# 0               0.05                     metric_rankme     0.651430
# 1               0.05                  metric_coherence     0.076665
# 2               0.05    metric_pseudo_condition_number    -0.240854
# 3               0.05                  metric_alpha_req    -0.442540
# 4               0.05                metric_stable_rank     0.483882
# ..               ...                               ...          ...
# 180             1.00  metric_ripser_sq_sum_H1_norm0.95     0.022511
# 181             1.00     metric_ripser_sum_H1_norm0.99     0.096507
# 182             1.00  metric_ripser_sq_sum_H1_norm0.99    -0.063410
# 183             1.00                   ripser_weighted     0.153382
# 184             1.00                       recall_topk     0.167791
#
# [185 rows x 3 columns]

# %%
mean_corr = corr_df[corr_df['sample_fraction'] > 0.0].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr
# Out:
# metric
# metric_ne_sum                       0.776370
# metric_ripser_sum_H0_norm0.95       0.680888
# metric_ripser_sum_H0_norm0.99       0.679713
# metric_ripser_sq_sum_H0_norm0.99    0.677349
# metric_ripser_sq_sum_H0_norm0.95    0.677268
# metric_ripser_sum_H0_norm0.9        0.675219
# metric_ripser_sq_sum_H0_norm0.9     0.670639
# metric_ripser_sum_H0_norm0.8        0.666851
# metric_ripser_sq_sum_H0_norm0.8     0.660791
# metric_ripser_sum_H0_norm0.7        0.660171
# metric_ripser_sq_sum_H0_norm0.7     0.652745
# metric_ripser_sum_H0_norm0.5        0.645734
# metric_ripser_sq_sum_H0_norm0.5     0.635044
# metric_stable_rank                  0.476761
# metric_self_clustering              0.421296
# metric_ripser_sq_sum_H1_norm0.5     0.297460
# metric_rankme                       0.281163
# metric_ripser_sq_sum_H1_norm0.7     0.225006
# metric_coherence                    0.203341
# metric_ripser_sum_H0                0.196014
# metric_ripser_sq_sum_H0             0.192540
# metric_pseudo_condition_number      0.182469
# metric_ripser_sq_sum_H1_norm0.8     0.179475
# recall_topk                         0.167791
# metric_ripser_sum_H1_norm0.5        0.164395
# ripser_weighted                     0.151140
# metric_ripser_sq_sum_H1_norm0.9     0.115136
# metric_ripser_sum_H1_norm0.7        0.106647
# metric_ripser_sum_H1                0.075307
# metric_ripser_sum_H1_norm0.8        0.072848
# metric_ripser_sq_sum_H1             0.066508
# metric_ripser_sq_sum_H1_norm0.95    0.063447
# metric_ripser_sum_H1_norm0.99       0.055117
# metric_ripser_sum_H1_norm0.9        0.027292
# metric_ripser_sum_H1_norm0.95      -0.007923
# metric_ripser_sq_sum_H1_norm0.99   -0.011704
# metric_alpha_req                   -0.308129
# Name: correlation, dtype: float64

# %%
mean_corr = corr_df[corr_df['sample_fraction'] > 0.8].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr
# Out:
# metric
# metric_ne_sum                       0.789824
# metric_ripser_sum_H0_norm0.99       0.688895
# metric_ripser_sq_sum_H0_norm0.99    0.685786
# metric_ripser_sum_H0_norm0.95       0.684186
# metric_ripser_sq_sum_H0_norm0.95    0.680107
# metric_ripser_sum_H0_norm0.9        0.678338
# metric_ripser_sq_sum_H0_norm0.9     0.673506
# metric_ripser_sum_H0_norm0.8        0.669669
# metric_ripser_sq_sum_H0_norm0.8     0.663658
# metric_ripser_sum_H0_norm0.7        0.662581
# metric_ripser_sq_sum_H0_norm0.7     0.655479
# metric_ripser_sum_H0_norm0.5        0.649135
# metric_ripser_sq_sum_H0_norm0.5     0.639560
# metric_stable_rank                  0.475364
# metric_self_clustering              0.421644
# metric_coherence                    0.309810
# metric_ripser_sq_sum_H1_norm0.5     0.283699
# metric_pseudo_condition_number      0.283628
# metric_ripser_sq_sum_H1_norm0.7     0.201597
# metric_ripser_sum_H0                0.201540
# metric_ripser_sq_sum_H0             0.198418
# recall_topk                         0.167791
# ripser_weighted                     0.153382
# metric_ripser_sum_H1_norm0.5        0.152071
# metric_ripser_sq_sum_H1_norm0.8     0.149999
# metric_rankme                       0.149755
# metric_ripser_sum_H1_norm0.99       0.096507
# metric_ripser_sum_H1                0.088372
# metric_ripser_sum_H1_norm0.7        0.087481
# metric_ripser_sq_sum_H1             0.078840
# metric_ripser_sq_sum_H1_norm0.9     0.078761
# metric_ripser_sum_H1_norm0.8        0.049500
# metric_ripser_sq_sum_H1_norm0.95    0.022511
# metric_ripser_sum_H1_norm0.9       -0.000836
# metric_ripser_sum_H1_norm0.95      -0.039483
# metric_ripser_sq_sum_H1_norm0.99   -0.063410
# metric_alpha_req                   -0.273695
# Name: correlation, dtype: float64

# %%
mean_corr = corr_df[corr_df['sample_fraction'] < 0.5].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr
# Out:
# metric
# metric_ne_sum                       0.757815
# metric_ripser_sum_H0_norm0.95       0.680887
# metric_ripser_sq_sum_H0_norm0.95    0.677920
# metric_ripser_sum_H0_norm0.9        0.674674
# metric_ripser_sum_H0_norm0.99       0.673644
# metric_ripser_sq_sum_H0_norm0.99    0.671949
# metric_ripser_sq_sum_H0_norm0.9     0.670614
# metric_ripser_sum_H0_norm0.8        0.665962
# metric_ripser_sq_sum_H0_norm0.8     0.660221
# metric_ripser_sum_H0_norm0.7        0.659397
# metric_ripser_sq_sum_H0_norm0.7     0.652108
# metric_ripser_sum_H0_norm0.5        0.642728
# metric_ripser_sq_sum_H0_norm0.5     0.631543
# metric_stable_rank                  0.482512
# metric_rankme                       0.451732
# metric_self_clustering              0.425954
# metric_ripser_sq_sum_H1_norm0.5     0.292447
# metric_ripser_sq_sum_H1_norm0.7     0.228459
# metric_ripser_sq_sum_H1_norm0.8     0.188961
# metric_ripser_sum_H0                0.188383
# metric_ripser_sq_sum_H0             0.184945
# recall_topk                         0.167791
# metric_ripser_sum_H1_norm0.5        0.166922
# ripser_weighted                     0.150152
# metric_ripser_sq_sum_H1_norm0.9     0.132296
# metric_coherence                    0.116174
# metric_ripser_sum_H1_norm0.7        0.116062
# metric_ripser_sum_H1_norm0.8        0.086763
# metric_ripser_sq_sum_H1_norm0.95    0.086695
# metric_ripser_sum_H1                0.065100
# metric_ripser_sq_sum_H1             0.058837
# metric_ripser_sum_H1_norm0.9        0.046686
# metric_ripser_sq_sum_H1_norm0.99    0.024722
# metric_pseudo_condition_number      0.024583
# metric_ripser_sum_H1_norm0.99       0.020982
# metric_ripser_sum_H1_norm0.95       0.015802
# metric_alpha_req                   -0.360291
# Name: correlation, dtype: float64

# %% [markdown]
# # Overall Spearmann Corr

# %%
mean_corr = spear_corr_df[spear_corr_df['sample_fraction'] > 0.8].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr.to_dict()
# Out:
# {'metric_ne_sum': 0.7527877033337171,
#  'metric_ripser_sum_H0_norm0.99': 0.6223052748346759,
#  'metric_ripser_sum_H0_norm0.95': 0.6204622719050549,
#  'metric_ripser_sq_sum_H0_norm0.99': 0.6194315028344373,
#  'metric_ripser_sq_sum_H0_norm0.95': 0.61730178357104,
#  'metric_ripser_sum_H0_norm0.9': 0.616328571611981,
#  'metric_ripser_sq_sum_H0_norm0.9': 0.6128823434410614,
#  'metric_ripser_sum_H0_norm0.8': 0.6109843564394296,
#  'metric_ripser_sum_H0_norm0.7': 0.6078419071152231,
#  'metric_ripser_sq_sum_H0_norm0.8': 0.607234976348941,
#  'metric_ripser_sq_sum_H0_norm0.7': 0.6035192325809143,
#  'metric_ripser_sum_H0_norm0.5': 0.6031181585486618,
#  'metric_ripser_sq_sum_H0_norm0.5': 0.5976552866288494,
#  'metric_rankme': 0.5750304044789676,
#  'metric_ripser_sum_H0': 0.5483556239379838,
#  'metric_ripser_sq_sum_H0': 0.5463448156034996,
#  'metric_coherence': 0.46024154959947977,
#  'metric_stable_rank': 0.4139165832944819,
#  'metric_self_clustering': 0.4016065810746243,
#  'ripser_weighted': 0.39507442433520124,
#  'metric_pseudo_condition_number': 0.3537185739872314,
#  'recall_topk': 0.3515304135512426,
#  'metric_ripser_sq_sum_H1_norm0.5': 0.34876876110452815,
#  'metric_ripser_sq_sum_H1_norm0.7': 0.28102260974966237,
#  'metric_alpha_req': 0.28086879711821433,
#  'metric_ripser_sq_sum_H1_norm0.8': 0.2388157095118568,
#  'metric_ripser_sum_H1_norm0.5': 0.2214576396648248,
#  'metric_ripser_sq_sum_H1': 0.2009724885367052,
#  'metric_ripser_sum_H1': 0.1961647307074977,
#  'metric_ripser_sq_sum_H1_norm0.9': 0.18114735849038366,
#  'metric_ripser_sum_H1_norm0.7': 0.16095704702163566,
#  'metric_ripser_sq_sum_H1_norm0.95': 0.1379758819672547,
#  'metric_ripser_sum_H1_norm0.8': 0.1295233836653652,
#  'metric_ripser_sum_H1_norm0.9': 0.08737263278564383,
#  'metric_ripser_sq_sum_H1_norm0.99': 0.0717081991876378,
#  'metric_ripser_sum_H1_norm0.95': 0.052427985202633934,
#  'metric_ripser_sum_H1_norm0.99': 0.0009343865702157888}

# %%
mean_corr = spear_corr_df[spear_corr_df['sample_fraction'] > 0.0].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr.to_dict()
# Out:
# {'metric_ne_sum': 0.7375726226958403,
#  'metric_ripser_sum_H0_norm0.99': 0.6098339468038647,
#  'metric_ripser_sum_H0_norm0.95': 0.6085455044355665,
#  'metric_ripser_sq_sum_H0_norm0.99': 0.6078831481537299,
#  'metric_ripser_sq_sum_H0_norm0.95': 0.6067326508556095,
#  'metric_ripser_sum_H0_norm0.9': 0.6042633963709175,
#  'metric_ripser_sq_sum_H0_norm0.9': 0.6018933316918168,
#  'metric_ripser_sum_H0_norm0.8': 0.5990650937918278,
#  'metric_ripser_sum_H0_norm0.7': 0.5960746078121747,
#  'metric_ripser_sq_sum_H0_norm0.8': 0.5959181250567654,
#  'metric_ripser_sq_sum_H0_norm0.7': 0.5924022856540447,
#  'metric_ripser_sum_H0_norm0.5': 0.5899006008956456,
#  'metric_ripser_sq_sum_H0_norm0.5': 0.5847920662947578,
#  'metric_rankme': 0.5823167938457865,
#  'metric_ripser_sum_H0': 0.5417119815190345,
#  'metric_ripser_sq_sum_H0': 0.5399524847160393,
#  'metric_stable_rank': 0.41486788478228265,
#  'metric_self_clustering': 0.4021662580402333,
#  'metric_coherence': 0.38348830557618363,
#  'ripser_weighted': 0.37707927536386987,
#  'metric_ripser_sq_sum_H1_norm0.5': 0.35775102202746434,
#  'recall_topk': 0.3515304135512426,
#  'metric_ripser_sq_sum_H1_norm0.7': 0.2970367230507027,
#  'metric_ripser_sq_sum_H1_norm0.8': 0.2572429212506357,
#  'metric_ripser_sum_H1_norm0.5': 0.22731720362714394,
#  'metric_ripser_sq_sum_H1_norm0.9': 0.20432739016004003,
#  'metric_pseudo_condition_number': 0.19695467480132256,
#  'metric_ripser_sum_H1_norm0.7': 0.17410878323597823,
#  'metric_ripser_sq_sum_H1_norm0.95': 0.16349991848994336,
#  'metric_ripser_sq_sum_H1': 0.14930820416205978,
#  'metric_ripser_sum_H1': 0.1457839656446287,
#  'metric_ripser_sum_H1_norm0.8': 0.14379054585197965,
#  'metric_ripser_sq_sum_H1_norm0.99': 0.10910805300394313,
#  'metric_alpha_req': 0.10867683878752499,
#  'metric_ripser_sum_H1_norm0.9': 0.10421198955842872,
#  'metric_ripser_sum_H1_norm0.95': 0.07332987917437064,
#  'metric_ripser_sum_H1_norm0.99': -0.03454775495528424}

# %%
mean_corr = spear_corr_df[spear_corr_df['sample_fraction'] < 0.4].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr.to_dict()
# Out:
# {'metric_ne_sum': 0.7170290265015158,
#  'metric_ripser_sum_H0_norm0.99': 0.6037554083708339,
#  'metric_ripser_sq_sum_H0_norm0.99': 0.6026535613397195,
#  'metric_ripser_sum_H0_norm0.95': 0.6000754199265562,
#  'metric_ripser_sq_sum_H0_norm0.95': 0.5995077741030432,
#  'metric_ripser_sum_H0_norm0.9': 0.5938333327538001,
#  'metric_ripser_sq_sum_H0_norm0.9': 0.5923551508327738,
#  'metric_rankme': 0.5922014580558853,
#  'metric_ripser_sum_H0_norm0.8': 0.5874573002440451,
#  'metric_ripser_sq_sum_H0_norm0.8': 0.5850424129272641,
#  'metric_ripser_sum_H0_norm0.7': 0.5845073259145999,
#  'metric_ripser_sq_sum_H0_norm0.7': 0.5815119087911788,
#  'metric_ripser_sum_H0_norm0.5': 0.5754598175742196,
#  'metric_ripser_sq_sum_H0_norm0.5': 0.5707321029880452,
#  'metric_ripser_sum_H0': 0.5343548403419707,
#  'metric_ripser_sq_sum_H0': 0.5330970670828865,
#  'metric_stable_rank': 0.41857784851592794,
#  'metric_self_clustering': 0.405732833107509,
#  'ripser_weighted': 0.3571799756843173,
#  'recall_topk': 0.3515304135512426,
#  'metric_ripser_sq_sum_H1_norm0.5': 0.3469543665015843,
#  'metric_ripser_sq_sum_H1_norm0.7': 0.2918975869086272,
#  'metric_coherence': 0.27475953112800255,
#  'metric_ripser_sq_sum_H1_norm0.8': 0.25800839537877,
#  'metric_ripser_sum_H1_norm0.5': 0.2254308026855378,
#  'metric_ripser_sq_sum_H1_norm0.9': 0.20950385920208098,
#  'metric_ripser_sum_H1_norm0.7': 0.18055399582128054,
#  'metric_ripser_sq_sum_H1_norm0.95': 0.17311430120449073,
#  'metric_ripser_sum_H1_norm0.8': 0.1541842492990992,
#  'metric_ripser_sq_sum_H1_norm0.99': 0.13580923036293596,
#  'metric_ripser_sum_H1_norm0.9': 0.12056999130069666,
#  'metric_ripser_sum_H1_norm0.95': 0.09549664217101861,
#  'metric_ripser_sum_H1': 0.0953005911401186,
#  'metric_ripser_sq_sum_H1': 0.09256085465325746,
#  'metric_pseudo_condition_number': -0.046602542947645376,
#  'metric_ripser_sum_H1_norm0.99': -0.0683323871213129,
#  'metric_alpha_req': -0.15368008699548522}

# %% [markdown]
# # Correlation for best checkpoint choice

# %%
mean_corr = spear_corr_df[spear_corr_df['sample_fraction'] > 0.8].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr.to_dict()
# Out:
# {'metric_ripser_sq_sum_H0_norm0.99': 0.6500669199140731,
#  'metric_ripser_sum_H0_norm0.99': 0.6496838826654516,
#  'metric_ripser_sum_H0_norm0.95': 0.6449501853643951,
#  'metric_ripser_sq_sum_H0_norm0.95': 0.6440540860747919,
#  'metric_ripser_sum_H0_norm0.9': 0.6421138269024252,
#  'metric_ripser_sq_sum_H0_norm0.9': 0.6415576884506674,
#  'metric_ripser_sum_H0_norm0.8': 0.6399140469252843,
#  'metric_ripser_sum_H0_norm0.7': 0.6342595603959449,
#  'metric_ripser_sq_sum_H0_norm0.8': 0.633001172610051,
#  'metric_ripser_sq_sum_H0_norm0.7': 0.6275150798353094,
#  'metric_ripser_sum_H0_norm0.5': 0.6175577259754601,
#  'metric_ripser_sq_sum_H0_norm0.5': 0.6172671597719305,
#  'recall_topk': 0.6152269455821133,
#  'metric_ne_sum': 0.602649524897968,
#  'metric_rankme': 0.5982548891112547,
#  'metric_ripser_sum_H0': 0.5440565735065103,
#  'metric_ripser_sq_sum_H0': 0.5434632557362932,
#  'metric_stable_rank': 0.5006791522100834,
#  'ripser_weighted': 0.49808504401734033,
#  'metric_self_clustering': 0.4975555465013753,
#  'metric_coherence': 0.43079313292123855,
#  'metric_pseudo_condition_number': 0.40188824930336753,
#  'metric_ripser_sq_sum_H1': 0.31339192364409735,
#  'metric_ripser_sum_H1': 0.3126153282833087,
#  'metric_alpha_req': 0.2841641594025315,
#  'metric_ripser_sum_H1_norm0.99': 0.23418067472846862,
#  'metric_ripser_sq_sum_H1_norm0.5': 0.1395564974015858,
#  'metric_ripser_sq_sum_H1_norm0.7': 0.03768265470229997,
#  'metric_ripser_sum_H1_norm0.5': -0.018655279998887723,
#  'metric_ripser_sq_sum_H1_norm0.8': -0.021543425475710812,
#  'metric_ripser_sum_H1_norm0.7': -0.06708859247000946,
#  'metric_ripser_sq_sum_H1_norm0.9': -0.07864976306891801,
#  'metric_ripser_sum_H1_norm0.8': -0.09450980435564918,
#  'metric_ripser_sq_sum_H1_norm0.95': -0.11644474153767938,
#  'metric_ripser_sum_H1_norm0.9': -0.14416169528594922,
#  'metric_ripser_sum_H1_norm0.95': -0.18046926020780632,
#  'metric_ripser_sq_sum_H1_norm0.99': -0.2037206088090825}

# %%
mean_corr = spear_corr_df[spear_corr_df['sample_fraction'] > 0.0].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr.to_dict()
# Out:
# {'metric_ripser_sum_H0_norm0.95': 0.6428464136331516,
#  'metric_ripser_sq_sum_H0_norm0.99': 0.6427202839775586,
#  'metric_ripser_sum_H0_norm0.99': 0.6425317179869401,
#  'metric_ripser_sq_sum_H0_norm0.95': 0.642044776405039,
#  'metric_ripser_sum_H0_norm0.9': 0.6406078582784963,
#  'metric_ripser_sq_sum_H0_norm0.9': 0.6385185003433623,
#  'metric_ripser_sum_H0_norm0.8': 0.6355369730571954,
#  'metric_ripser_sq_sum_H0_norm0.8': 0.6310642573990053,
#  'metric_ripser_sum_H0_norm0.7': 0.6288489473513404,
#  'metric_ripser_sq_sum_H0_norm0.7': 0.6254563742718529,
#  'metric_ripser_sum_H0_norm0.5': 0.6168123027221684,
#  'metric_ripser_sq_sum_H0_norm0.5': 0.6153503487755165,
#  'recall_topk': 0.6152269455821134,
#  'metric_ne_sum': 0.6048739378799646,
#  'metric_rankme': 0.598857392164167,
#  'metric_ripser_sq_sum_H0': 0.5433127622281603,
#  'metric_ripser_sum_H0': 0.543303718784519,
#  'metric_stable_rank': 0.4975770371611221,
#  'metric_self_clustering': 0.4933724018707662,
#  'ripser_weighted': 0.4592684735750628,
#  'metric_coherence': 0.42798695954174226,
#  'metric_ripser_sum_H1': 0.2694603161923099,
#  'metric_ripser_sq_sum_H1': 0.2572795141384376,
#  'metric_pseudo_condition_number': 0.21418685945131546,
#  'metric_ripser_sum_H1_norm0.99': 0.20240473237961376,
#  'metric_ripser_sq_sum_H1_norm0.5': 0.15593846466635197,
#  'metric_alpha_req': 0.09993813291979713,
#  'metric_ripser_sq_sum_H1_norm0.7': 0.07216646310166769,
#  'metric_ripser_sq_sum_H1_norm0.8': 0.023818964560662945,
#  'metric_ripser_sum_H1_norm0.5': 0.003447265131481661,
#  'metric_ripser_sq_sum_H1_norm0.9': -0.036128678237450244,
#  'metric_ripser_sum_H1_norm0.7': -0.04826569969735065,
#  'metric_ripser_sum_H1_norm0.8': -0.07887435736012868,
#  'metric_ripser_sq_sum_H1_norm0.95': -0.08104851596708226,
#  'metric_ripser_sum_H1_norm0.9': -0.12358299152936042,
#  'metric_ripser_sq_sum_H1_norm0.99': -0.1508445830305192,
#  'metric_ripser_sum_H1_norm0.95': -0.1567824676957289}

# %%
mean_corr = spear_corr_df[spear_corr_df['sample_fraction'] < 0.5].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr.to_dict()
# Out:
# {'metric_ripser_sum_H0_norm0.95': 0.6413706412368186,
#  'metric_ripser_sq_sum_H0_norm0.95': 0.6404664412160206,
#  'metric_ripser_sum_H0_norm0.9': 0.638219154577555,
#  'metric_ripser_sq_sum_H0_norm0.9': 0.6364264377831752,
#  'metric_ripser_sq_sum_H0_norm0.99': 0.6328624166163707,
#  'metric_ripser_sum_H0_norm0.99': 0.6328270061107243,
#  'metric_ripser_sum_H0_norm0.8': 0.6313569504967045,
#  'metric_ripser_sq_sum_H0_norm0.8': 0.6282972155535097,
#  'metric_ripser_sum_H0_norm0.7': 0.6260662875752045,
#  'metric_ripser_sq_sum_H0_norm0.7': 0.6247687514480913,
#  'metric_ripser_sum_H0_norm0.5': 0.6156876064071433,
#  'recall_topk': 0.6152269455821133,
#  'metric_ripser_sq_sum_H0_norm0.5': 0.6141995560141752,
#  'metric_ne_sum': 0.6100549178712131,
#  'metric_rankme': 0.5984230589088614,
#  'metric_ripser_sq_sum_H0': 0.5434566132162798,
#  'metric_ripser_sum_H0': 0.5431509973189618,
#  'metric_stable_rank': 0.49570127491262156,
#  'metric_self_clustering': 0.49047083365536753,
#  'metric_coherence': 0.43098531045834515,
#  'ripser_weighted': 0.4141064602710214,
#  'metric_ripser_sum_H1': 0.22624078312463322,
#  'metric_ripser_sq_sum_H1': 0.20377096652023227,
#  'metric_ripser_sum_H1_norm0.99': 0.15031301780098447,
#  'metric_ripser_sq_sum_H1_norm0.5': 0.14801252280444144,
#  'metric_ripser_sq_sum_H1_norm0.7': 0.07703796299806022,
#  'metric_ripser_sq_sum_H1_norm0.8': 0.037959048784772534,
#  'metric_ripser_sum_H1_norm0.5': 0.012922568832180934,
#  'metric_ripser_sq_sum_H1_norm0.9': -0.014945612401071527,
#  'metric_ripser_sum_H1_norm0.7': -0.030583347675757315,
#  'metric_pseudo_condition_number': -0.04804072136275028,
#  'metric_ripser_sq_sum_H1_norm0.95': -0.053265461055119645,
#  'metric_ripser_sum_H1_norm0.8': -0.057118214831516356,
#  'metric_ripser_sum_H1_norm0.9': -0.0932108065672934,
#  'metric_ripser_sq_sum_H1_norm0.99': -0.09781700119426635,
#  'metric_ripser_sum_H1_norm0.95': -0.12052321333327372,
#  'metric_alpha_req': -0.18532976314886127}

# %% [markdown]
# # Linear correlation of epoch choice

# %%
mean_corr = corr_df[corr_df['sample_fraction'] > 0.8].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr
# Out:
# metric
# metric_ripser_sum_H0_norm0.99       0.792933
# metric_ripser_sq_sum_H0_norm0.99    0.792744
# metric_ripser_sum_H0_norm0.95       0.782797
# metric_ripser_sq_sum_H0_norm0.95    0.781463
# recall_topk                         0.779455
# metric_ripser_sum_H0_norm0.9        0.774805
# metric_ripser_sq_sum_H0_norm0.9     0.772398
# metric_ripser_sum_H0_norm0.8        0.762093
# metric_ripser_sq_sum_H0_norm0.8     0.757474
# metric_ne_sum                       0.756413
# metric_ripser_sum_H0_norm0.7        0.750782
# metric_ripser_sq_sum_H0_norm0.7     0.743979
# metric_rankme                       0.739781
# metric_ripser_sum_H0_norm0.5        0.727590
# metric_ripser_sq_sum_H0_norm0.5     0.717657
# metric_ripser_sum_H0                0.676706
# metric_ripser_sq_sum_H0             0.676552
# ripser_weighted                     0.656132
# metric_stable_rank                  0.618789
# metric_self_clustering              0.602423
# metric_ripser_sq_sum_H1             0.586892
# metric_ripser_sum_H1                0.584421
# metric_ripser_sum_H1_norm0.99       0.556731
# metric_coherence                    0.528752
# metric_pseudo_condition_number      0.378230
# metric_alpha_req                    0.190873
# metric_ripser_sq_sum_H1_norm0.5     0.026093
# metric_ripser_sq_sum_H1_norm0.7    -0.123499
# metric_ripser_sum_H1_norm0.5       -0.189333
# metric_ripser_sq_sum_H1_norm0.8    -0.213169
# metric_ripser_sum_H1_norm0.7       -0.298133
# metric_ripser_sq_sum_H1_norm0.9    -0.327690
# metric_ripser_sum_H1_norm0.8       -0.357748
# metric_ripser_sq_sum_H1_norm0.95   -0.411168
# metric_ripser_sum_H1_norm0.9       -0.430831
# metric_ripser_sum_H1_norm0.95      -0.482807
# metric_ripser_sq_sum_H1_norm0.99   -0.532070
# Name: correlation, dtype: float64

# %%
mean_corr = corr_df[corr_df['sample_fraction'] < 0.4].groupby("metric")["correlation"].mean().sort_values(ascending=False)
mean_corr
# Out:
# metric
# metric_ripser_sum_H0_norm0.95       0.781943
# metric_ripser_sq_sum_H0_norm0.95    0.781072
# recall_topk                         0.779455
# metric_ripser_sum_H0_norm0.9        0.775626
# metric_ripser_sq_sum_H0_norm0.9     0.772848
# metric_ripser_sum_H0_norm0.8        0.764276
# metric_ripser_sum_H0_norm0.99       0.763446
# metric_ripser_sq_sum_H0_norm0.99    0.763283
# metric_ripser_sq_sum_H0_norm0.8     0.758719
# metric_ne_sum                       0.754274
# metric_rankme                       0.752587
# metric_ripser_sum_H0_norm0.7        0.752106
# metric_ripser_sq_sum_H0_norm0.7     0.744804
# metric_ripser_sum_H0_norm0.5        0.730334
# metric_ripser_sq_sum_H0_norm0.5     0.721234
# metric_ripser_sq_sum_H0             0.677401
# metric_ripser_sum_H0                0.677340
# ripser_weighted                     0.621661
# metric_stable_rank                  0.615556
# metric_self_clustering              0.597950
# metric_coherence                    0.523680
# metric_ripser_sum_H1                0.472660
# metric_ripser_sq_sum_H1             0.457787
# metric_ripser_sum_H1_norm0.99       0.393431
# metric_ripser_sq_sum_H1_norm0.5     0.089105
# metric_ripser_sq_sum_H1_norm0.7    -0.020098
# metric_ripser_sq_sum_H1_norm0.8    -0.087104
# metric_ripser_sum_H1_norm0.5       -0.130278
# metric_pseudo_condition_number     -0.144170
# metric_ripser_sq_sum_H1_norm0.9    -0.180353
# metric_ripser_sum_H1_norm0.7       -0.211838
# metric_ripser_sq_sum_H1_norm0.95   -0.253012
# metric_ripser_sum_H1_norm0.8       -0.257012
# metric_alpha_req                   -0.301008
# metric_ripser_sum_H1_norm0.9       -0.314590
# metric_ripser_sq_sum_H1_norm0.99   -0.318327
# metric_ripser_sum_H1_norm0.95      -0.357525
# Name: correlation, dtype: float64

# %% [markdown]
# # Score of best epoch

# %%
corr_df = pd.DataFrame(corr_records)
mean_corr = corr_df[corr_df['sample_fraction'] > 0.0].groupby("metric")["auc"].mean().sort_values(ascending=False)
mean_corr.to_dict()
# Out:
# {'metric_ripser_sum_H0_norm0.9': 0.7133673684210527,
#  'metric_ripser_sum_H0_norm0.8': 0.7128526315789474,
#  'metric_ripser_sum_H0_norm0.95': 0.7127463157894737,
#  'metric_ripser_sq_sum_H0_norm0.95': 0.7126463157894738,
#  'recall_topk': 0.7126368421052632,
#  'metric_ripser_sum_H0_norm0.99': 0.7124157894736842,
#  'metric_ripser_sq_sum_H0_norm0.99': 0.7120452631578947,
#  'metric_ne_sum': 0.711321052631579,
#  'metric_ripser_sq_sum_H0_norm0.9': 0.7108463157894737,
#  'metric_ripser_sum_H0_norm0.7': 0.7098378947368421,
#  'metric_rankme': 0.7082231578947368,
#  'metric_ripser_sq_sum_H0_norm0.8': 0.7076231578947368,
#  'metric_ripser_sq_sum_H0_norm0.7': 0.7073957894736842,
#  'metric_ripser_sq_sum_H0_norm0.5': 0.7071968421052631,
#  'metric_ripser_sum_H0_norm0.5': 0.7057905263157894,
#  'metric_coherence': 0.7044473684210526,
#  'metric_ripser_sum_H0': 0.704238947368421,
#  'metric_ripser_sq_sum_H0': 0.703021052631579,
#  'ripser_weighted': 0.7009273684210526,
#  'metric_ripser_sum_H1': 0.6890294736842106,
#  'metric_stable_rank': 0.6880452631578947,
#  'metric_self_clustering': 0.6868452631578947,
#  'metric_ripser_sum_H1_norm0.99': 0.6855526315789473,
#  'metric_ripser_sq_sum_H1': 0.6834031578947368,
#  'metric_ripser_sq_sum_H1_norm0.5': 0.6485821052631578,
#  'metric_pseudo_condition_number': 0.646845054945055,
#  'metric_alpha_req': 0.6357073684210527,
#  'metric_ripser_sq_sum_H1_norm0.7': 0.6194515789473685,
#  'metric_ripser_sq_sum_H1_norm0.8': 0.6075336842105263,
#  'metric_ripser_sum_H1_norm0.5': 0.6067547368421052,
#  'metric_ripser_sum_H1_norm0.7': 0.605881052631579,
#  'metric_ripser_sq_sum_H1_norm0.9': 0.60322,
#  'metric_ripser_sum_H1_norm0.8': 0.5997915789473683,
#  'metric_ripser_sum_H1_norm0.9': 0.5950526315789474,
#  'metric_ripser_sq_sum_H1_norm0.95': 0.5947842105263158,
#  'metric_ripser_sum_H1_norm0.95': 0.5936084210526316,
#  'metric_ripser_sq_sum_H1_norm0.99': 0.5892336842105262}

# %%
mean_corr = corr_df[corr_df['sample_fraction'] > 0.8].groupby("metric")["auc"].mean().sort_values(ascending=False)
mean_corr.to_dict()
# Out:
# {'metric_ne_sum': 0.7158947368421053,
#  'metric_ripser_sum_H0_norm0.95': 0.7143473684210526,
#  'metric_ripser_sq_sum_H0_norm0.95': 0.7143473684210526,
#  'metric_ripser_sq_sum_H0_norm0.9': 0.7140947368421052,
#  'metric_ripser_sum_H0_norm0.8': 0.7138789473684211,
#  'metric_ripser_sum_H0_norm0.9': 0.7138789473684211,
#  'metric_ripser_sq_sum_H0_norm0.99': 0.7130526315789474,
#  'metric_ripser_sum_H0_norm0.7': 0.7127105263157895,
#  'recall_topk': 0.7126368421052632,
#  'metric_ripser_sum_H0_norm0.99': 0.7125789473684211,
#  'metric_coherence': 0.7072157894736842,
#  'metric_ripser_sq_sum_H0_norm0.8': 0.7068631578947369,
#  'metric_ripser_sq_sum_H0_norm0.7': 0.7068421052631578,
#  'metric_ripser_sq_sum_H0_norm0.5': 0.7064526315789473,
#  'metric_rankme': 0.7050263157894737,
#  'metric_ripser_sq_sum_H0': 0.7047315789473685,
#  'metric_ripser_sum_H0': 0.7047315789473685,
#  'metric_ripser_sum_H0_norm0.5': 0.7026105263157895,
#  'ripser_weighted': 0.7021421052631579,
#  'metric_stable_rank': 0.6894526315789474,
#  'metric_self_clustering': 0.6894526315789474,
#  'metric_ripser_sum_H1_norm0.99': 0.6879157894736841,
#  'metric_ripser_sum_H1': 0.6878842105263159,
#  'metric_ripser_sq_sum_H1': 0.6858052631578948,
#  'metric_pseudo_condition_number': 0.6630055555555556,
#  'metric_alpha_req': 0.6496526315789474,
#  'metric_ripser_sq_sum_H1_norm0.5': 0.6369473684210526,
#  'metric_ripser_sum_H1_norm0.7': 0.6052526315789474,
#  'metric_ripser_sum_H1_norm0.5': 0.6052526315789474,
#  'metric_ripser_sq_sum_H1_norm0.7': 0.5971,
#  'metric_ripser_sq_sum_H1_norm0.8': 0.5971,
#  'metric_ripser_sum_H1_norm0.8': 0.5957631578947368,
#  'metric_ripser_sq_sum_H1_norm0.9': 0.594021052631579,
#  'metric_ripser_sq_sum_H1_norm0.95': 0.5864947368421053,
#  'metric_ripser_sq_sum_H1_norm0.99': 0.5864947368421053,
#  'metric_ripser_sum_H1_norm0.95': 0.5864947368421053,
#  'metric_ripser_sum_H1_norm0.9': 0.584378947368421}

# %%
mean_corr = corr_df[corr_df['sample_fraction'] < 0.4].groupby("metric")["auc"].mean().sort_values(ascending=False)
mean_corr.to_dict()
# Out:
# {'metric_ne_sum': 0.7131,
#  'metric_ripser_sum_H0_norm0.8': 0.7128342105263158,
#  'metric_ripser_sum_H0_norm0.9': 0.7128315789473685,
#  'recall_topk': 0.7126368421052632,
#  'metric_ripser_sq_sum_H0_norm0.95': 0.7123421052631579,
#  'metric_ripser_sum_H0_norm0.95': 0.7119342105263158,
#  'metric_rankme': 0.7116289473684211,
#  'metric_ripser_sum_H0_norm0.99': 0.7112105263157895,
#  'metric_ripser_sq_sum_H0_norm0.99': 0.7112105263157895,
#  'metric_ripser_sq_sum_H0_norm0.5': 0.7102421052631579,
#  'metric_ripser_sq_sum_H0_norm0.8': 0.7096552631578947,
#  'metric_ripser_sum_H0_norm0.7': 0.7091736842105263,
#  'metric_ripser_sq_sum_H0_norm0.7': 0.7091078947368421,
#  'metric_ripser_sum_H0_norm0.5': 0.7087447368421053,
#  'metric_ripser_sq_sum_H0_norm0.9': 0.70685,
#  'metric_ripser_sum_H0': 0.7032736842105263,
#  'metric_ripser_sq_sum_H0': 0.7022342105263157,
#  'metric_coherence': 0.7009052631578947,
#  'ripser_weighted': 0.6998184210526316,
#  'metric_ripser_sum_H1': 0.689828947368421,
#  'metric_stable_rank': 0.6885394736842105,
#  'metric_ripser_sum_H1_norm0.99': 0.6869263157894737,
#  'metric_self_clustering': 0.6842368421052631,
#  'metric_ripser_sq_sum_H1': 0.6810026315789474,
#  'metric_ripser_sq_sum_H1_norm0.5': 0.6575605263157895,
#  'metric_ripser_sq_sum_H1_norm0.7': 0.6465342105263158,
#  'metric_pseudo_condition_number': 0.6275189189189189,
#  'metric_ripser_sq_sum_H1_norm0.8': 0.6266842105263158,
#  'metric_ripser_sum_H1_norm0.5': 0.6189105263157895,
#  'metric_ripser_sq_sum_H1_norm0.9': 0.6183105263157894,
#  'metric_ripser_sum_H1_norm0.7': 0.6177578947368421,
#  'metric_alpha_req': 0.6130657894736842,
#  'metric_ripser_sum_H1_norm0.8': 0.6116184210526315,
#  'metric_ripser_sq_sum_H1_norm0.95': 0.6073447368421053,
#  'metric_ripser_sum_H1_norm0.9': 0.6059447368421053,
#  'metric_ripser_sum_H1_norm0.95': 0.6021473684210527,
#  'metric_ripser_sq_sum_H1_norm0.99': 0.5951394736842106}

# %% [markdown]
# # Corr of scores to metric by different hyperparams

# %%
for param in params_cols:
    corr_df = pd.DataFrame(corr_records[param])
    mean_corr = corr_df[corr_df['sample_fraction'] < 0.5].groupby("metric")["corr"].mean().sort_values(ascending=False)
    print(param)
    print(mean_corr)
# Out:
# batch_size
# metric
# metric_ripser_sq_sum_H0             0.682775
# metric_ripser_sum_H0                0.681125
# metric_ripser_sq_sum_H0_norm0.95    0.603899
# metric_ripser_sq_sum_H0_norm0.99    0.601692
# metric_ripser_sum_H0_norm0.95       0.600355
# metric_ripser_sum_H0_norm0.99       0.597713
# metric_ripser_sq_sum_H0_norm0.9     0.588726
# metric_ripser_sum_H0_norm0.9        0.585739
# metric_ne_sum                       0.582928
# metric_ripser_sq_sum_H0_norm0.7     0.572117
# metric_ripser_sq_sum_H0_norm0.8     0.569963
# metric_ripser_sum_H0_norm0.7        0.569736
# metric_ripser_sum_H0_norm0.8        0.569089
# metric_rankme                       0.567482
# metric_ripser_sq_sum_H0_norm0.5     0.558373
# metric_stable_rank                  0.555089
# metric_ripser_sum_H0_norm0.5        0.554117
# metric_self_clustering              0.544144
# metric_coherence                    0.526158
# ripser_weighted                     0.373404
# metric_ripser_sq_sum_H1_norm0.5     0.321221
# metric_ripser_sq_sum_H1_norm0.7     0.225215
# metric_ripser_sum_H1_norm0.5        0.201002
# metric_ripser_sq_sum_H1             0.191507
# metric_ripser_sq_sum_H1_norm0.8     0.185610
# metric_ripser_sum_H1_norm0.7        0.149183
# metric_ripser_sum_H1                0.134055
# metric_ripser_sum_H1_norm0.8        0.125846
# metric_ripser_sq_sum_H1_norm0.9     0.124427
# metric_ripser_sum_H1_norm0.9        0.097152
# metric_ripser_sq_sum_H1_norm0.95    0.082155
# metric_ripser_sum_H1_norm0.95       0.075211
# metric_ripser_sq_sum_H1_norm0.99    0.058512
# metric_pseudo_condition_number      0.039585
# metric_ripser_sum_H1_norm0.99      -0.041010
# metric_alpha_req                   -0.091525
# recall_topk                        -0.119725
# Name: corr, dtype: float64
# learning_rate
# metric
# metric_ne_sum                       0.830210
# metric_coherence                    0.748772
# metric_rankme                       0.650715
# metric_ripser_sum_H0                0.458033
# metric_ripser_sq_sum_H0             0.457786
# metric_ripser_sum_H0_norm0.5        0.433112
# metric_ripser_sum_H0_norm0.7        0.431100
# metric_ripser_sq_sum_H0_norm0.5     0.430587
# metric_ripser_sq_sum_H0_norm0.7     0.429972
# metric_ripser_sum_H0_norm0.8        0.425623
# metric_ripser_sum_H0_norm0.9        0.425576
# metric_ripser_sq_sum_H0_norm0.9     0.424570
# metric_ripser_sq_sum_H0_norm0.8     0.424487
# metric_ripser_sum_H0_norm0.95       0.422831
# metric_ripser_sq_sum_H0_norm0.95    0.422439
# metric_ripser_sum_H0_norm0.99       0.406853
# metric_ripser_sq_sum_H0_norm0.99    0.405368
# metric_ripser_sq_sum_H1_norm0.5     0.401136
# metric_ripser_sq_sum_H1_norm0.7     0.368991
# metric_ripser_sq_sum_H1_norm0.8     0.344952
# metric_ripser_sum_H1_norm0.5        0.332454
# metric_ripser_sq_sum_H1_norm0.9     0.299058
# metric_ripser_sum_H1_norm0.7        0.289151
# metric_stable_rank                  0.278348
# metric_self_clustering              0.276376
# metric_ripser_sq_sum_H1_norm0.95    0.271136
# metric_ripser_sum_H1_norm0.8        0.266380
# metric_ripser_sq_sum_H1_norm0.99    0.254551
# metric_ripser_sum_H1_norm0.9        0.234494
# metric_ripser_sum_H1_norm0.95       0.218669
# ripser_weighted                     0.202887
# metric_ripser_sum_H1               -0.073693
# metric_ripser_sq_sum_H1            -0.097601
# recall_topk                        -0.144581
# metric_ripser_sum_H1_norm0.99      -0.185030
# metric_pseudo_condition_number     -0.248813
# metric_alpha_req                   -0.360592
# Name: corr, dtype: float64
# split_count
# metric
# metric_ripser_sum_H0_norm0.7        0.856929
# metric_ripser_sq_sum_H0_norm0.7     0.856092
# metric_ripser_sq_sum_H0_norm0.9     0.855696
# metric_ripser_sum_H0_norm0.9        0.854944
# metric_ripser_sq_sum_H0_norm0.8     0.851459
# metric_ripser_sum_H0_norm0.8        0.850803
# metric_ripser_sq_sum_H0_norm0.95    0.847476
# metric_ripser_sum_H0_norm0.95       0.846774
# metric_ripser_sum_H0_norm0.5        0.840034
# metric_ripser_sq_sum_H0_norm0.5     0.837696
# metric_ripser_sq_sum_H0_norm0.99    0.776104
# metric_ripser_sum_H0_norm0.99       0.774286
# metric_ne_sum                       0.758759
# metric_rankme                       0.714687
# metric_stable_rank                  0.597827
# metric_self_clustering              0.595184
# metric_ripser_sum_H0                0.589884
# metric_ripser_sq_sum_H0             0.589543
# metric_ripser_sq_sum_H1_norm0.5     0.586193
# metric_ripser_sq_sum_H1_norm0.7     0.549531
# metric_ripser_sq_sum_H1_norm0.8     0.535114
# metric_ripser_sq_sum_H1_norm0.9     0.486174
# metric_coherence                    0.467186
# metric_ripser_sq_sum_H1_norm0.95    0.455239
# metric_ripser_sum_H1_norm0.5        0.427246
# metric_ripser_sq_sum_H1_norm0.99    0.419573
# metric_ripser_sum_H1_norm0.7        0.377842
# metric_ripser_sum_H1_norm0.8        0.362369
# metric_ripser_sum_H1_norm0.9        0.343130
# metric_ripser_sum_H1_norm0.95       0.327903
# recall_topk                         0.248678
# ripser_weighted                     0.131846
# metric_pseudo_condition_number      0.080134
# metric_alpha_req                   -0.144354
# metric_ripser_sum_H1               -0.158999
# metric_ripser_sq_sum_H1            -0.198528
# metric_ripser_sum_H1_norm0.99      -0.268313
# Name: corr, dtype: float64
# cnt_min
# metric
# metric_ripser_sum_H0                0.748171
# metric_ripser_sq_sum_H0             0.747971
# metric_ripser_sq_sum_H0_norm0.95    0.660420
# metric_ripser_sum_H0_norm0.95       0.658909
# metric_rankme                       0.657207
# metric_ripser_sum_H0_norm0.9        0.643279
# metric_ripser_sq_sum_H0_norm0.9     0.641713
# metric_ripser_sq_sum_H0_norm0.99    0.640239
# metric_ripser_sum_H0_norm0.99       0.639239
# metric_ripser_sum_H0_norm0.8        0.630454
# metric_ripser_sq_sum_H0_norm0.8     0.629769
# metric_ripser_sq_sum_H0_norm0.7     0.629186
# metric_ripser_sum_H0_norm0.7        0.628500
# metric_ripser_sq_sum_H0_norm0.5     0.618697
# metric_ripser_sum_H0_norm0.5        0.617857
# metric_ne_sum                       0.597755
# metric_coherence                    0.576531
# metric_stable_rank                  0.565647
# metric_self_clustering              0.562666
# metric_ripser_sq_sum_H1_norm0.5     0.512820
# metric_ripser_sq_sum_H1_norm0.7     0.467202
# metric_ripser_sq_sum_H1_norm0.8     0.441403
# metric_ripser_sq_sum_H1_norm0.9     0.384509
# metric_ripser_sum_H1_norm0.5        0.373854
# ripser_weighted                     0.359739
# metric_ripser_sq_sum_H1_norm0.95    0.344246
# metric_ripser_sum_H1_norm0.7        0.322515
# metric_ripser_sum_H1_norm0.8        0.298575
# metric_ripser_sq_sum_H1_norm0.99    0.280397
# metric_ripser_sum_H1_norm0.9        0.270977
# metric_ripser_sum_H1_norm0.95       0.245059
# metric_ripser_sq_sum_H1             0.041040
# metric_pseudo_condition_number      0.023581
# metric_ripser_sum_H1                0.012142
# metric_alpha_req                   -0.107552
# recall_topk                        -0.116759
# metric_ripser_sum_H1_norm0.99      -0.181074
# Name: corr, dtype: float64
# cnt_max
# metric
# metric_ripser_sum_H0                0.732439
# metric_ripser_sq_sum_H0             0.732253
# metric_ripser_sq_sum_H0_norm0.95    0.721937
# metric_ripser_sum_H0_norm0.95       0.721184
# metric_ripser_sq_sum_H0_norm0.9     0.715652
# metric_ripser_sum_H0_norm0.9        0.714080
# metric_rankme                       0.711625
# metric_ripser_sq_sum_H0_norm0.99    0.711103
# metric_ripser_sum_H0_norm0.99       0.710012
# metric_ripser_sq_sum_H0_norm0.8     0.704288
# metric_ripser_sq_sum_H0_norm0.7     0.702572
# metric_ripser_sum_H0_norm0.8        0.702465
# metric_ripser_sum_H0_norm0.7        0.701960
# metric_ripser_sq_sum_H0_norm0.5     0.698688
# metric_ripser_sum_H0_norm0.5        0.698277
# metric_ne_sum                       0.690510
# metric_stable_rank                  0.661744
# metric_self_clustering              0.655396
# metric_coherence                    0.574064
# metric_ripser_sq_sum_H1_norm0.5     0.500331
# metric_ripser_sq_sum_H1_norm0.7     0.465184
# metric_ripser_sq_sum_H1_norm0.8     0.445714
# metric_ripser_sq_sum_H1_norm0.9     0.406917
# metric_ripser_sq_sum_H1_norm0.95    0.376808
# metric_ripser_sum_H1_norm0.5        0.374350
# metric_ripser_sq_sum_H1_norm0.99    0.338335
# metric_ripser_sum_H1_norm0.7        0.335314
# metric_ripser_sum_H1_norm0.8        0.314229
# metric_ripser_sum_H1_norm0.9        0.291778
# metric_ripser_sum_H1_norm0.95       0.273003
# ripser_weighted                     0.095054
# metric_pseudo_condition_number     -0.020123
# recall_topk                        -0.095459
# metric_ripser_sum_H1               -0.131183
# metric_ripser_sq_sum_H1            -0.182002
# metric_alpha_req                   -0.189852
# metric_ripser_sum_H1_norm0.99      -0.228756
# Name: corr, dtype: float64
# embedding_dim
# metric
# metric_ripser_sq_sum_H0_norm0.99    0.821643
# metric_ripser_sum_H0_norm0.99       0.820425
# metric_ripser_sq_sum_H0_norm0.95    0.817178
# metric_ripser_sum_H0_norm0.95       0.816281
# metric_ripser_sq_sum_H0_norm0.9     0.813413
# metric_ripser_sum_H0_norm0.9        0.811786
# metric_ripser_sq_sum_H0_norm0.7     0.804975
# metric_ripser_sq_sum_H0_norm0.8     0.804101
# metric_rankme                       0.803799
# metric_ripser_sum_H0_norm0.7        0.803317
# metric_ripser_sum_H0_norm0.8        0.802840
# metric_ne_sum                       0.797451
# metric_ripser_sq_sum_H0_norm0.5     0.794778
# metric_ripser_sum_H0_norm0.5        0.792643
# metric_stable_rank                  0.777865
# metric_self_clustering              0.772627
# metric_ripser_sq_sum_H0             0.761429
# metric_ripser_sum_H0                0.761181
# metric_ripser_sq_sum_H1_norm0.5     0.668822
# recall_topk                         0.636152
# metric_ripser_sq_sum_H1_norm0.7     0.626134
# metric_ripser_sq_sum_H1_norm0.8     0.602022
# metric_ripser_sq_sum_H1_norm0.9     0.567223
# metric_ripser_sq_sum_H1_norm0.95    0.547695
# metric_ripser_sum_H1_norm0.5        0.528556
# metric_ripser_sq_sum_H1_norm0.99    0.509218
# metric_ripser_sum_H1_norm0.7        0.491189
# ripser_weighted                     0.487788
# metric_ripser_sum_H1_norm0.8        0.469817
# metric_ripser_sum_H1_norm0.9        0.443885
# metric_ripser_sum_H1_norm0.95       0.427760
# metric_coherence                    0.264151
# metric_pseudo_condition_number      0.039064
# metric_alpha_req                   -0.065833
# metric_ripser_sum_H1               -0.113119
# metric_ripser_sq_sum_H1            -0.127666
# metric_ripser_sum_H1_norm0.99      -0.383522
# Name: corr, dtype: float64
# category_embedding_dim
# metric
# metric_ripser_sum_H0                0.708837
# metric_ripser_sq_sum_H0             0.707871
# metric_rankme                       0.704679
# metric_ripser_sum_H0_norm0.99       0.680497
# metric_ripser_sum_H0_norm0.95       0.679875
# metric_ripser_sq_sum_H0_norm0.95    0.676820
# metric_ripser_sq_sum_H0_norm0.99    0.674312
# metric_ripser_sum_H0_norm0.9        0.655696
# metric_ripser_sq_sum_H0_norm0.9     0.650739
# metric_ripser_sum_H0_norm0.8        0.636811
# metric_ripser_sq_sum_H0_norm0.8     0.626941
# metric_ripser_sum_H0_norm0.7        0.626162
# metric_ripser_sq_sum_H0_norm0.7     0.609232
# metric_coherence                    0.580915
# metric_ripser_sum_H0_norm0.5        0.576649
# metric_ripser_sq_sum_H0_norm0.5     0.551346
# metric_ne_sum                       0.535123
# ripser_weighted                     0.445700
# metric_stable_rank                  0.380696
# metric_self_clustering              0.365685
# metric_ripser_sq_sum_H1             0.259944
# metric_ripser_sum_H1                0.259713
# metric_ripser_sum_H1_norm0.99       0.163349
# metric_ripser_sq_sum_H1_norm0.5     0.052897
# metric_ripser_sq_sum_H1_norm0.7     0.020524
# metric_ripser_sq_sum_H1_norm0.8     0.004126
# metric_ripser_sq_sum_H1_norm0.9    -0.032201
# metric_ripser_sum_H1_norm0.5       -0.054112
# metric_ripser_sq_sum_H1_norm0.95   -0.060594
# metric_pseudo_condition_number     -0.073645
# metric_ripser_sum_H1_norm0.7       -0.086200
# metric_ripser_sq_sum_H1_norm0.99   -0.094779
# metric_ripser_sum_H1_norm0.8       -0.098458
# metric_ripser_sum_H1_norm0.9       -0.115552
# metric_ripser_sum_H1_norm0.95      -0.130829
# metric_alpha_req                   -0.194169
# recall_topk                        -0.197666
# Name: corr, dtype: float64
# hidden_size
# metric
# metric_ripser_sum_H0_norm0.99       0.599185
# metric_ripser_sq_sum_H0_norm0.99    0.598279
# metric_ne_sum                       0.548821
# metric_ripser_sum_H0_norm0.95       0.502060
# metric_ripser_sq_sum_H0_norm0.95    0.501204
# metric_ripser_sum_H0_norm0.9        0.498629
# metric_ripser_sq_sum_H0_norm0.9     0.496248
# metric_ripser_sum_H0_norm0.7        0.490673
# metric_ripser_sum_H0_norm0.8        0.490481
# metric_ripser_sq_sum_H0_norm0.8     0.486846
# metric_ripser_sq_sum_H0_norm0.7     0.485705
# metric_ripser_sum_H0_norm0.5        0.471497
# metric_ripser_sq_sum_H0_norm0.5     0.466530
# metric_ripser_sum_H0                0.455777
# metric_ripser_sq_sum_H0             0.453754
# metric_stable_rank                  0.441538
# metric_rankme                       0.439528
# metric_self_clustering              0.424426
# metric_ripser_sq_sum_H1_norm0.5     0.295012
# ripser_weighted                     0.268889
# metric_coherence                    0.266796
# metric_ripser_sq_sum_H1_norm0.7     0.260755
# metric_ripser_sq_sum_H1_norm0.8     0.235318
# metric_ripser_sum_H1_norm0.5        0.212714
# metric_ripser_sq_sum_H1_norm0.9     0.185923
# metric_ripser_sum_H1_norm0.7        0.173626
# metric_ripser_sum_H1_norm0.8        0.154112
# metric_ripser_sq_sum_H1_norm0.95    0.147022
# metric_ripser_sum_H1_norm0.9        0.126615
# metric_ripser_sq_sum_H1_norm0.99    0.108974
# recall_topk                         0.106616
# metric_ripser_sum_H1_norm0.95       0.104279
# metric_pseudo_condition_number      0.027562
# metric_alpha_req                    0.022825
# metric_ripser_sum_H1                0.009477
# metric_ripser_sq_sum_H1            -0.007336
# metric_ripser_sum_H1_norm0.99      -0.065522
# Name: corr, dtype: float64

# %% [markdown]
# # Score of best hyperparams selected by metric

# %%
for param in params_cols:
    corr_df = pd.DataFrame(corr_records[param])
    mean_corr = corr_df[corr_df['sample_fraction'] < 0.5].groupby("metric")["auc"].mean().sort_values(ascending=False)
    print(param)
    print(mean_corr)
# Out:
# batch_size
# metric
# metric_self_clustering              0.76940
# recall_topk                         0.76810
# metric_stable_rank                  0.76750
# metric_ripser_sq_sum_H0             0.73910
# metric_ripser_sum_H0                0.73910
# metric_coherence                    0.71740
# metric_ripser_sum_H0_norm0.5        0.71180
# metric_ripser_sq_sum_H0_norm0.5     0.71180
# metric_ripser_sq_sum_H1             0.71015
# metric_ne_sum                       0.70705
# metric_ripser_sq_sum_H1_norm0.5     0.69790
# metric_rankme                       0.69385
# metric_ripser_sum_H0_norm0.95       0.68900
# metric_ripser_sq_sum_H0_norm0.95    0.68900
# ripser_weighted                     0.68890
# metric_ripser_sum_H1_norm0.99       0.68855
# metric_ripser_sum_H0_norm0.7        0.68450
# metric_ripser_sum_H0_norm0.9        0.68450
# metric_ripser_sq_sum_H0_norm0.9     0.68450
# metric_ripser_sq_sum_H0_norm0.7     0.68450
# metric_ripser_sq_sum_H0_norm0.8     0.68450
# metric_ripser_sum_H0_norm0.8        0.68450
# metric_ripser_sum_H0_norm0.99       0.68425
# metric_ripser_sq_sum_H0_norm0.99    0.68425
# metric_ripser_sum_H1                0.68205
# metric_ripser_sq_sum_H1_norm0.8     0.66250
# metric_alpha_req                    0.64380
# metric_ripser_sum_H1_norm0.7        0.64000
# metric_ripser_sq_sum_H1_norm0.9     0.64000
# metric_ripser_sq_sum_H1_norm0.7     0.64000
# metric_ripser_sq_sum_H1_norm0.95    0.64000
# metric_ripser_sum_H1_norm0.5        0.64000
# metric_pseudo_condition_number      0.63815
# metric_ripser_sum_H1_norm0.8        0.61010
# metric_ripser_sum_H1_norm0.95       0.61010
# metric_ripser_sum_H1_norm0.9        0.61010
# metric_ripser_sq_sum_H1_norm0.99    0.55560
# Name: auc, dtype: float64
# learning_rate
# metric
# metric_ne_sum                       0.75840
# metric_ripser_sum_H0_norm0.7        0.74945
# metric_ripser_sq_sum_H0_norm0.9     0.74945
# metric_ripser_sq_sum_H0_norm0.7     0.74945
# metric_ripser_sq_sum_H0_norm0.8     0.74945
# metric_ripser_sum_H0_norm0.8        0.74945
# metric_ripser_sum_H0_norm0.9        0.74945
# metric_ripser_sum_H0_norm0.95       0.74070
# metric_ripser_sq_sum_H0_norm0.95    0.74070
# metric_coherence                    0.73520
# metric_ripser_sq_sum_H0_norm0.5     0.73485
# metric_ripser_sum_H0_norm0.5        0.73485
# recall_topk                         0.73310
# metric_ripser_sq_sum_H0_norm0.99    0.67920
# metric_ripser_sum_H0_norm0.99       0.67920
# metric_ripser_sq_sum_H1_norm0.9     0.67815
# metric_ripser_sq_sum_H1_norm0.7     0.67815
# metric_ripser_sq_sum_H1_norm0.8     0.67815
# metric_ripser_sq_sum_H1_norm0.5     0.67815
# metric_stable_rank                  0.67510
# metric_self_clustering              0.67510
# metric_rankme                       0.67200
# metric_ripser_sum_H1_norm0.7        0.64515
# metric_ripser_sum_H1_norm0.95       0.64515
# metric_ripser_sum_H1_norm0.9        0.64515
# metric_ripser_sum_H1_norm0.5        0.64515
# metric_ripser_sum_H1_norm0.8        0.64515
# metric_pseudo_condition_number      0.63640
# metric_ripser_sum_H1_norm0.99       0.61885
# metric_ripser_sq_sum_H1_norm0.95    0.59825
# metric_alpha_req                    0.58895
# metric_ripser_sum_H1                0.58780
# ripser_weighted                     0.58780
# metric_ripser_sq_sum_H1_norm0.99    0.58085
# metric_ripser_sq_sum_H1             0.57980
# metric_ripser_sum_H0                0.56680
# metric_ripser_sq_sum_H0             0.56680
# Name: auc, dtype: float64
# split_count
# metric
# metric_ripser_sq_sum_H0_norm0.5     0.77215
# metric_ripser_sum_H0_norm0.5        0.77215
# recall_topk                         0.77010
# metric_ripser_sq_sum_H0_norm0.95    0.75630
# metric_ripser_sum_H0_norm0.95       0.75630
# metric_coherence                    0.75510
# metric_ripser_sum_H0_norm0.8        0.75495
# metric_ripser_sum_H0_norm0.7        0.75495
# metric_ripser_sq_sum_H0_norm0.7     0.75495
# metric_ne_sum                       0.75330
# metric_ripser_sq_sum_H0_norm0.9     0.74845
# metric_ripser_sum_H0_norm0.9        0.74845
# metric_ripser_sq_sum_H0_norm0.8     0.74845
# metric_ripser_sq_sum_H0_norm0.99    0.74595
# metric_ripser_sum_H0_norm0.99       0.74595
# metric_rankme                       0.73910
# metric_ripser_sq_sum_H0             0.73910
# metric_ripser_sum_H0                0.73910
# metric_ripser_sq_sum_H1_norm0.5     0.72995
# metric_ripser_sq_sum_H1_norm0.7     0.72995
# metric_self_clustering              0.71630
# metric_stable_rank                  0.71630
# metric_ripser_sum_H1_norm0.7        0.71610
# metric_ripser_sq_sum_H1_norm0.9     0.71610
# metric_ripser_sum_H1_norm0.5        0.71610
# metric_ripser_sq_sum_H1_norm0.8     0.71610
# metric_ripser_sum_H1                0.70175
# metric_ripser_sum_H1_norm0.99       0.70175
# metric_ripser_sq_sum_H1             0.68870
# metric_ripser_sum_H1_norm0.8        0.68245
# metric_ripser_sum_H1_norm0.9        0.68245
# metric_ripser_sq_sum_H1_norm0.95    0.68245
# metric_ripser_sq_sum_H1_norm0.99    0.68245
# ripser_weighted                     0.68165
# metric_pseudo_condition_number      0.67280
# metric_alpha_req                    0.65635
# metric_ripser_sum_H1_norm0.95       0.64860
# Name: auc, dtype: float64
# cnt_min
# metric
# metric_ripser_sq_sum_H0             0.73910
# metric_ripser_sum_H0                0.73910
# metric_ripser_sq_sum_H0_norm0.7     0.72230
# metric_ripser_sq_sum_H0_norm0.5     0.72230
# metric_ripser_sum_H0_norm0.5        0.72230
# metric_ne_sum                       0.71550
# metric_ripser_sum_H0_norm0.9        0.71460
# metric_ripser_sum_H0_norm0.8        0.71460
# metric_ripser_sum_H0_norm0.7        0.71460
# metric_ripser_sum_H0_norm0.95       0.71460
# metric_ripser_sq_sum_H0_norm0.95    0.71460
# metric_ripser_sq_sum_H0_norm0.9     0.71460
# metric_ripser_sq_sum_H0_norm0.8     0.71460
# metric_ripser_sum_H1_norm0.99       0.71135
# metric_ripser_sum_H1                0.71135
# metric_ripser_sq_sum_H0_norm0.99    0.70845
# metric_ripser_sum_H0_norm0.99       0.70845
# metric_rankme                       0.70425
# metric_coherence                    0.69840
# metric_ripser_sq_sum_H1             0.69625
# recall_topk                         0.69430
# ripser_weighted                     0.69125
# metric_stable_rank                  0.66990
# metric_self_clustering              0.66990
# metric_pseudo_condition_number      0.66560
# metric_ripser_sq_sum_H1_norm0.5     0.60725
# metric_ripser_sq_sum_H1_norm0.95    0.59210
# metric_ripser_sq_sum_H1_norm0.9     0.59210
# metric_ripser_sq_sum_H1_norm0.99    0.59210
# metric_ripser_sum_H1_norm0.7        0.57335
# metric_ripser_sq_sum_H1_norm0.8     0.57335
# metric_ripser_sq_sum_H1_norm0.7     0.57335
# metric_ripser_sum_H1_norm0.5        0.57335
# metric_ripser_sum_H1_norm0.8        0.56820
# metric_ripser_sum_H1_norm0.95       0.56820
# metric_ripser_sum_H1_norm0.9        0.56820
# metric_alpha_req                    0.52810
# Name: auc, dtype: float64
# cnt_max
# metric
# recall_topk                         0.74510
# metric_ripser_sq_sum_H1_norm0.5     0.74445
# metric_ne_sum                       0.73810
# metric_rankme                       0.73740
# metric_coherence                    0.73740
# metric_ripser_sum_H0_norm0.8        0.73520
# metric_ripser_sum_H0_norm0.9        0.73520
# metric_ripser_sq_sum_H0_norm0.8     0.73520
# metric_ripser_sq_sum_H0_norm0.5     0.73520
# metric_ripser_sq_sum_H0_norm0.99    0.73520
# metric_ripser_sq_sum_H0_norm0.95    0.73520
# metric_ripser_sum_H0_norm0.5        0.73520
# metric_ripser_sq_sum_H0_norm0.7     0.73520
# metric_ripser_sum_H0_norm0.7        0.73520
# metric_ripser_sq_sum_H0_norm0.9     0.73520
# metric_ripser_sum_H0_norm0.95       0.73520
# metric_ripser_sum_H0_norm0.99       0.73520
# metric_ripser_sum_H0                0.73300
# metric_ripser_sq_sum_H0             0.73300
# metric_self_clustering              0.71860
# metric_stable_rank                  0.71860
# metric_ripser_sq_sum_H1_norm0.7     0.69275
# metric_ripser_sq_sum_H1_norm0.8     0.69275
# ripser_weighted                     0.68090
# metric_pseudo_condition_number      0.66560
# metric_ripser_sq_sum_H1_norm0.9     0.66275
# metric_ripser_sq_sum_H1_norm0.95    0.66275
# metric_ripser_sum_H1                0.65715
# metric_ripser_sum_H1_norm0.99       0.65715
# metric_ripser_sq_sum_H1             0.65055
# metric_ripser_sum_H1_norm0.8        0.61980
# metric_ripser_sum_H1_norm0.7        0.61980
# metric_ripser_sum_H1_norm0.5        0.61980
# metric_ripser_sum_H1_norm0.9        0.61980
# metric_ripser_sum_H1_norm0.95       0.61980
# metric_ripser_sq_sum_H1_norm0.99    0.58710
# metric_alpha_req                    0.55355
# Name: auc, dtype: float64
# embedding_dim
# metric
# recall_topk                         0.77200
# metric_ripser_sq_sum_H0_norm0.9     0.76180
# metric_coherence                    0.75840
# metric_ripser_sq_sum_H0_norm0.99    0.75570
# metric_ripser_sum_H0_norm0.99       0.75570
# metric_ripser_sum_H0_norm0.7        0.74665
# metric_ripser_sum_H0_norm0.9        0.74665
# metric_ripser_sum_H0_norm0.8        0.74665
# metric_ripser_sq_sum_H0_norm0.7     0.74665
# metric_ripser_sq_sum_H0_norm0.8     0.74665
# metric_ripser_sum_H0_norm0.5        0.74665
# metric_ripser_sq_sum_H0_norm0.5     0.74665
# metric_rankme                       0.74480
# metric_ne_sum                       0.74185
# metric_ripser_sq_sum_H0_norm0.95    0.74055
# metric_ripser_sq_sum_H1             0.73080
# metric_self_clustering              0.73030
# metric_stable_rank                  0.73030
# metric_ripser_sum_H0_norm0.95       0.72540
# metric_ripser_sum_H0                0.72540
# metric_ripser_sq_sum_H0             0.72540
# metric_ripser_sum_H1                0.72300
# ripser_weighted                     0.72300
# metric_ripser_sum_H1_norm0.99       0.71470
# metric_ripser_sum_H1_norm0.5        0.71175
# metric_ripser_sq_sum_H1_norm0.8     0.71175
# metric_ripser_sq_sum_H1_norm0.5     0.71175
# metric_ripser_sq_sum_H1_norm0.7     0.71175
# metric_ripser_sq_sum_H1_norm0.9     0.71175
# metric_ripser_sum_H1_norm0.8        0.65635
# metric_ripser_sum_H1_norm0.9        0.65635
# metric_ripser_sum_H1_norm0.7        0.65635
# metric_ripser_sum_H1_norm0.95       0.65635
# metric_alpha_req                    0.65260
# metric_ripser_sq_sum_H1_norm0.95    0.64670
# metric_ripser_sq_sum_H1_norm0.99    0.64670
# metric_pseudo_condition_number      0.63975
# Name: auc, dtype: float64
# category_embedding_dim
# metric
# recall_topk                         0.71570
# metric_ripser_sq_sum_H0_norm0.5     0.70060
# metric_ripser_sum_H0_norm0.5        0.70060
# metric_ripser_sq_sum_H0_norm0.99    0.70030
# metric_rankme                       0.70030
# metric_ripser_sum_H0_norm0.99       0.70030
# ripser_weighted                     0.70030
# metric_ripser_sum_H0_norm0.95       0.70030
# metric_ripser_sq_sum_H0             0.70030
# metric_ripser_sum_H0                0.70030
# metric_ripser_sq_sum_H0_norm0.95    0.70030
# metric_coherence                    0.69840
# metric_ripser_sq_sum_H0_norm0.8     0.69735
# metric_ripser_sum_H0_norm0.8        0.69735
# metric_ne_sum                       0.69640
# metric_ripser_sum_H0_norm0.9        0.69445
# metric_ripser_sq_sum_H0_norm0.9     0.69445
# metric_ripser_sq_sum_H0_norm0.7     0.68860
# metric_ripser_sum_H0_norm0.7        0.68860
# metric_stable_rank                  0.68640
# metric_self_clustering              0.68640
# metric_ripser_sq_sum_H1             0.68110
# metric_ripser_sum_H1_norm0.99       0.68110
# metric_ripser_sum_H1                0.68110
# metric_alpha_req                    0.66245
# metric_pseudo_condition_number      0.64645
# metric_ripser_sq_sum_H1_norm0.5     0.62255
# metric_ripser_sq_sum_H1_norm0.7     0.62255
# metric_ripser_sq_sum_H1_norm0.9     0.62255
# metric_ripser_sum_H1_norm0.7        0.62255
# metric_ripser_sq_sum_H1_norm0.95    0.62255
# metric_ripser_sq_sum_H1_norm0.8     0.62255
# metric_ripser_sum_H1_norm0.5        0.62255
# metric_ripser_sum_H1_norm0.8        0.62255
# metric_ripser_sum_H1_norm0.95       0.62255
# metric_ripser_sum_H1_norm0.9        0.62255
# metric_ripser_sq_sum_H1_norm0.99    0.59455
# Name: auc, dtype: float64
# hidden_size
# metric
# recall_topk                         0.74770
# metric_ne_sum                       0.72165
# metric_ripser_sq_sum_H0_norm0.99    0.72160
# metric_ripser_sum_H0_norm0.99       0.72160
# metric_alpha_req                    0.71110
# metric_ripser_sq_sum_H0_norm0.8     0.71070
# metric_ripser_sum_H0_norm0.8        0.71070
# metric_ripser_sq_sum_H0_norm0.5     0.71070
# metric_ripser_sq_sum_H0_norm0.95    0.70595
# metric_ripser_sum_H0_norm0.9        0.70575
# metric_ripser_sq_sum_H0_norm0.9     0.70575
# metric_ripser_sum_H0_norm0.7        0.70235
# metric_ripser_sq_sum_H0_norm0.7     0.70235
# metric_ripser_sum_H1_norm0.99       0.69805
# metric_ripser_sum_H0_norm0.95       0.69725
# metric_ripser_sq_sum_H1_norm0.7     0.68150
# metric_ripser_sum_H1_norm0.5        0.68150
# metric_ripser_sq_sum_H1_norm0.9     0.68150
# metric_ripser_sq_sum_H1_norm0.8     0.68150
# metric_ripser_sq_sum_H1_norm0.5     0.68150
# metric_ripser_sum_H0_norm0.5        0.67260
# metric_ripser_sq_sum_H1_norm0.99    0.67055
# metric_rankme                       0.66940
# metric_self_clustering              0.66410
# metric_stable_rank                  0.66410
# metric_ripser_sum_H1_norm0.8        0.65960
# metric_ripser_sum_H1_norm0.9        0.65960
# metric_ripser_sum_H1_norm0.95       0.65960
# metric_ripser_sq_sum_H1_norm0.95    0.65960
# metric_ripser_sum_H1_norm0.7        0.65960
# metric_ripser_sum_H1                0.64630
# metric_pseudo_condition_number      0.63805
# metric_coherence                    0.59085
# metric_ripser_sq_sum_H1             0.58410
# ripser_weighted                     0.58410
# metric_ripser_sum_H0                0.56010
# metric_ripser_sq_sum_H0             0.56010
# Name: auc, dtype: float64

# %%
for param in params_cols:
    corr_df = pd.DataFrame(corr_records[param])
    mean_corr = corr_df[corr_df['sample_fraction'] > 0.8].groupby("metric")["auc"].mean().sort_values(ascending=False)
    print(param)
    print(mean_corr)
# Out:
# batch_size
# metric
# metric_stable_rank                  0.7694
# metric_self_clustering              0.7694
# recall_topk                         0.7681
# metric_pseudo_condition_number      0.7567
# metric_rankme                       0.7391
# metric_ripser_sum_H0_norm0.7        0.7391
# metric_ripser_sum_H0_norm0.95       0.7391
# metric_ripser_sum_H0_norm0.8        0.7391
# metric_ripser_sq_sum_H0             0.7391
# metric_ripser_sq_sum_H0_norm0.95    0.7391
# metric_ripser_sq_sum_H0_norm0.7     0.7391
# metric_ripser_sq_sum_H0_norm0.8     0.7391
# metric_ripser_sq_sum_H0_norm0.9     0.7391
# metric_ripser_sum_H0                0.7391
# metric_ripser_sum_H0_norm0.9        0.7391
# metric_alpha_req                    0.7320
# ripser_weighted                     0.7273
# metric_ripser_sum_H0_norm0.5        0.7256
# metric_ripser_sq_sum_H0_norm0.5     0.7256
# metric_ne_sum                       0.7241
# metric_ripser_sum_H1_norm0.99       0.7088
# metric_ripser_sq_sum_H1             0.7088
# metric_ripser_sum_H1                0.7088
# metric_coherence                    0.6984
# metric_ripser_sum_H0_norm0.99       0.6900
# metric_ripser_sq_sum_H0_norm0.99    0.6900
# metric_ripser_sq_sum_H1_norm0.5     0.5556
# metric_ripser_sq_sum_H1_norm0.7     0.5556
# metric_ripser_sq_sum_H1_norm0.9     0.5556
# metric_ripser_sq_sum_H1_norm0.95    0.5556
# metric_ripser_sq_sum_H1_norm0.99    0.5556
# metric_ripser_sq_sum_H1_norm0.8     0.5556
# metric_ripser_sum_H1_norm0.5        0.5556
# metric_ripser_sum_H1_norm0.7        0.5556
# metric_ripser_sum_H1_norm0.95       0.5556
# metric_ripser_sum_H1_norm0.8        0.5556
# metric_ripser_sum_H1_norm0.9        0.5556
# Name: auc, dtype: float64
# learning_rate
# metric
# metric_ne_sum                       0.7658
# metric_coherence                    0.7366
# metric_ripser_sq_sum_H0_norm0.99    0.7366
# metric_ripser_sum_H0_norm0.99       0.7366
# metric_ripser_sq_sum_H0_norm0.8     0.7331
# metric_ripser_sum_H0_norm0.8        0.7331
# metric_ripser_sum_H0_norm0.9        0.7331
# recall_topk                         0.7331
# metric_ripser_sq_sum_H0_norm0.5     0.7331
# metric_ripser_sq_sum_H0_norm0.95    0.7331
# metric_ripser_sq_sum_H0_norm0.9     0.7331
# metric_ripser_sum_H0_norm0.5        0.7331
# metric_ripser_sq_sum_H0_norm0.7     0.7331
# metric_ripser_sum_H0_norm0.7        0.7331
# metric_ripser_sum_H0_norm0.95       0.7331
# metric_ripser_sum_H1_norm0.9        0.6800
# metric_ripser_sum_H1_norm0.8        0.6800
# metric_ripser_sum_H1_norm0.95       0.6800
# metric_ripser_sq_sum_H1_norm0.95    0.6800
# metric_ripser_sq_sum_H1_norm0.9     0.6800
# metric_ripser_sq_sum_H1_norm0.5     0.6800
# metric_ripser_sq_sum_H1_norm0.7     0.6800
# metric_ripser_sq_sum_H1_norm0.8     0.6800
# metric_ripser_sum_H1_norm0.7        0.6800
# metric_ripser_sum_H1_norm0.5        0.6800
# metric_stable_rank                  0.6751
# metric_rankme                       0.6720
# metric_pseudo_condition_number      0.6337
# metric_ripser_sq_sum_H0             0.6004
# metric_ripser_sum_H0                0.6004
# metric_alpha_req                    0.5981
# ripser_weighted                     0.5958
# metric_ripser_sum_H1                0.5866
# metric_ripser_sum_H1_norm0.99       0.5866
# metric_ripser_sq_sum_H1             0.5798
# metric_ripser_sq_sum_H1_norm0.99    0.5324
# metric_self_clustering              0.4976
# Name: auc, dtype: float64
# split_count
# metric
# metric_ripser_sq_sum_H1_norm0.5     0.7701
# recall_topk                         0.7701
# metric_ripser_sq_sum_H0_norm0.8     0.7628
# metric_ripser_sq_sum_H0_norm0.5     0.7628
# metric_ripser_sum_H0_norm0.5        0.7628
# metric_ripser_sum_H0_norm0.7        0.7628
# metric_ripser_sum_H0_norm0.8        0.7628
# metric_ripser_sq_sum_H0_norm0.7     0.7628
# metric_coherence                    0.7551
# metric_ripser_sum_H0_norm0.9        0.7498
# metric_ripser_sq_sum_H0_norm0.95    0.7498
# metric_ripser_sum_H0_norm0.95       0.7498
# metric_ne_sum                       0.7498
# metric_ripser_sq_sum_H0_norm0.99    0.7498
# metric_ripser_sq_sum_H0_norm0.9     0.7498
# metric_ripser_sum_H0_norm0.99       0.7498
# metric_alpha_req                    0.7471
# metric_ripser_sum_H0                0.7391
# metric_rankme                       0.7391
# metric_ripser_sq_sum_H0             0.7391
# metric_pseudo_condition_number      0.7330
# ripser_weighted                     0.7273
# metric_self_clustering              0.7163
# metric_stable_rank                  0.7163
# metric_ripser_sum_H1_norm0.99       0.7088
# metric_ripser_sum_H1                0.7088
# metric_ripser_sq_sum_H1             0.7088
# metric_ripser_sq_sum_H1_norm0.7     0.6486
# metric_ripser_sq_sum_H1_norm0.9     0.6486
# metric_ripser_sq_sum_H1_norm0.95    0.6486
# metric_ripser_sq_sum_H1_norm0.99    0.6486
# metric_ripser_sq_sum_H1_norm0.8     0.6486
# metric_ripser_sum_H1_norm0.5        0.6486
# metric_ripser_sum_H1_norm0.7        0.6486
# metric_ripser_sum_H1_norm0.95       0.6486
# metric_ripser_sum_H1_norm0.8        0.6486
# metric_ripser_sum_H1_norm0.9        0.6486
# Name: auc, dtype: float64
# cnt_min
# metric
# metric_ripser_sq_sum_H0             0.7391
# metric_ripser_sum_H0                0.7391
# ripser_weighted                     0.7273
# metric_pseudo_condition_number      0.7263
# metric_ne_sum                       0.7241
# metric_ripser_sq_sum_H0_norm0.5     0.7223
# metric_ripser_sum_H0_norm0.5        0.7223
# metric_stable_rank                  0.7194
# metric_self_clustering              0.7194
# metric_ripser_sum_H1                0.7088
# metric_ripser_sum_H1_norm0.99       0.7088
# metric_ripser_sq_sum_H1             0.7088
# metric_coherence                    0.7069
# metric_ripser_sum_H0_norm0.99       0.7069
# metric_ripser_sum_H0_norm0.95       0.7069
# metric_ripser_sum_H0_norm0.7        0.7069
# metric_ripser_sq_sum_H0_norm0.95    0.7069
# metric_ripser_sq_sum_H0_norm0.99    0.7069
# metric_ripser_sq_sum_H0_norm0.9     0.7069
# metric_ripser_sq_sum_H0_norm0.8     0.7069
# metric_ripser_sq_sum_H0_norm0.7     0.7069
# metric_ripser_sum_H0_norm0.9        0.7069
# metric_ripser_sum_H0_norm0.8        0.7069
# metric_rankme                       0.6985
# metric_alpha_req                    0.6963
# recall_topk                         0.6943
# metric_ripser_sq_sum_H1_norm0.5     0.5708
# metric_ripser_sq_sum_H1_norm0.7     0.5708
# metric_ripser_sq_sum_H1_norm0.9     0.5708
# metric_ripser_sum_H1_norm0.7        0.5708
# metric_ripser_sq_sum_H1_norm0.95    0.5708
# metric_ripser_sq_sum_H1_norm0.8     0.5708
# metric_ripser_sum_H1_norm0.5        0.5708
# metric_ripser_sum_H1_norm0.8        0.5708
# metric_ripser_sum_H1_norm0.95       0.5708
# metric_ripser_sum_H1_norm0.9        0.5708
# metric_ripser_sq_sum_H1_norm0.99    0.5281
# Name: auc, dtype: float64
# cnt_max
# metric
# recall_topk                         0.7451
# metric_ripser_sq_sum_H0_norm0.5     0.7388
# metric_ripser_sum_H0_norm0.5        0.7388
# metric_rankme                       0.7374
# metric_ne_sum                       0.7330
# metric_ripser_sum_H0                0.7330
# metric_ripser_sum_H0_norm0.9        0.7330
# metric_ripser_sum_H0_norm0.95       0.7330
# metric_ripser_sq_sum_H0_norm0.7     0.7330
# metric_ripser_sq_sum_H0_norm0.9     0.7330
# metric_ripser_sq_sum_H0_norm0.95    0.7330
# metric_ripser_sq_sum_H0_norm0.99    0.7330
# metric_ripser_sq_sum_H0             0.7330
# metric_ripser_sum_H0_norm0.8        0.7330
# metric_ripser_sq_sum_H0_norm0.8     0.7330
# metric_ripser_sum_H0_norm0.7        0.7330
# metric_ripser_sum_H0_norm0.99       0.7330
# metric_stable_rank                  0.7186
# metric_self_clustering              0.7186
# metric_ripser_sq_sum_H1             0.7101
# metric_coherence                    0.7083
# metric_pseudo_condition_number      0.6605
# metric_ripser_sum_H1                0.6441
# ripser_weighted                     0.6441
# metric_ripser_sum_H1_norm0.99       0.6441
# metric_alpha_req                    0.5786
# metric_ripser_sq_sum_H1_norm0.5     0.5786
# metric_ripser_sq_sum_H1_norm0.7     0.5786
# metric_ripser_sq_sum_H1_norm0.9     0.5786
# metric_ripser_sq_sum_H1_norm0.95    0.5786
# metric_ripser_sq_sum_H1_norm0.99    0.5786
# metric_ripser_sq_sum_H1_norm0.8     0.5786
# metric_ripser_sum_H1_norm0.5        0.5786
# metric_ripser_sum_H1_norm0.7        0.5786
# metric_ripser_sum_H1_norm0.95       0.5786
# metric_ripser_sum_H1_norm0.8        0.5786
# metric_ripser_sum_H1_norm0.9        0.5786
# Name: auc, dtype: float64
# embedding_dim
# metric
# metric_stable_rank                  0.7755
# metric_self_clustering              0.7755
# metric_coherence                    0.7725
# recall_topk                         0.7720
# metric_ripser_sq_sum_H0_norm0.99    0.7711
# metric_ripser_sum_H0_norm0.99       0.7711
# metric_ripser_sq_sum_H0_norm0.95    0.7711
# metric_ripser_sum_H0_norm0.7        0.7590
# metric_ripser_sum_H0_norm0.95       0.7590
# metric_ripser_sum_H0_norm0.8        0.7590
# metric_ripser_sum_H0_norm0.9        0.7590
# metric_ripser_sq_sum_H0_norm0.8     0.7590
# metric_ripser_sq_sum_H0_norm0.7     0.7590
# metric_ripser_sq_sum_H0_norm0.9     0.7590
# metric_ne_sum                       0.7579
# metric_rankme                       0.7557
# metric_ripser_sum_H1_norm0.7        0.7467
# metric_ripser_sum_H1_norm0.5        0.7467
# metric_ripser_sq_sum_H1_norm0.8     0.7467
# metric_ripser_sq_sum_H1_norm0.7     0.7467
# metric_ripser_sq_sum_H1_norm0.5     0.7467
# metric_ripser_sq_sum_H1_norm0.9     0.7467
# metric_ripser_sum_H1                0.7370
# ripser_weighted                     0.7370
# metric_alpha_req                    0.7332
# metric_ripser_sum_H0                0.7254
# metric_ripser_sq_sum_H0             0.7254
# metric_ripser_sum_H0_norm0.5        0.7254
# metric_ripser_sq_sum_H0_norm0.5     0.7254
# metric_ripser_sum_H1_norm0.99       0.7088
# metric_pseudo_condition_number      0.6969
# metric_ripser_sq_sum_H1             0.6913
# metric_ripser_sq_sum_H1_norm0.99    0.6083
# metric_ripser_sq_sum_H1_norm0.95    0.6083
# metric_ripser_sum_H1_norm0.95       0.6083
# metric_ripser_sum_H1_norm0.8        0.6083
# metric_ripser_sum_H1_norm0.9        0.6083
# Name: auc, dtype: float64
# category_embedding_dim
# metric
# recall_topk                         0.7157
# metric_ne_sum                       0.7052
# metric_rankme                       0.7003
# metric_ripser_sq_sum_H0             0.7003
# metric_ripser_sum_H0                0.7003
# metric_coherence                    0.6984
# metric_pseudo_condition_number      0.6921
# ripser_weighted                     0.6886
# metric_ripser_sq_sum_H0_norm0.7     0.6886
# metric_ripser_sq_sum_H0_norm0.9     0.6886
# metric_ripser_sq_sum_H0_norm0.95    0.6886
# metric_ripser_sq_sum_H0_norm0.99    0.6886
# metric_ripser_sq_sum_H0_norm0.5     0.6886
# metric_ripser_sq_sum_H1             0.6886
# metric_ripser_sum_H0_norm0.5        0.6886
# metric_ripser_sum_H1                0.6886
# metric_ripser_sum_H0_norm0.99       0.6886
# metric_ripser_sum_H0_norm0.8        0.6886
# metric_ripser_sum_H0_norm0.9        0.6886
# metric_ripser_sum_H0_norm0.7        0.6886
# metric_ripser_sq_sum_H0_norm0.8     0.6886
# metric_ripser_sum_H1_norm0.99       0.6886
# metric_ripser_sum_H0_norm0.95       0.6886
# metric_alpha_req                    0.6864
# metric_stable_rank                  0.6864
# metric_self_clustering              0.6864
# metric_ripser_sq_sum_H1_norm0.5     0.5975
# metric_ripser_sq_sum_H1_norm0.7     0.5975
# metric_ripser_sq_sum_H1_norm0.9     0.5975
# metric_ripser_sq_sum_H1_norm0.95    0.5975
# metric_ripser_sq_sum_H1_norm0.99    0.5975
# metric_ripser_sq_sum_H1_norm0.8     0.5975
# metric_ripser_sum_H1_norm0.5        0.5975
# metric_ripser_sum_H1_norm0.7        0.5975
# metric_ripser_sum_H1_norm0.95       0.5975
# metric_ripser_sum_H1_norm0.8        0.5975
# metric_ripser_sum_H1_norm0.9        0.5975
# Name: auc, dtype: float64
# hidden_size
# metric
# metric_alpha_req                    0.7617
# metric_ne_sum                       0.7617
# recall_topk                         0.7477
# metric_ripser_sum_H1_norm0.99       0.7088
# metric_ripser_sq_sum_H0_norm0.99    0.7029
# metric_ripser_sum_H1_norm0.7        0.7012
# metric_ripser_sum_H1_norm0.5        0.7012
# metric_ripser_sum_H0_norm0.99       0.6939
# metric_ripser_sum_H0_norm0.9        0.6815
# metric_ripser_sum_H0_norm0.7        0.6815
# metric_ripser_sum_H0_norm0.95       0.6815
# metric_ripser_sq_sum_H0_norm0.9     0.6815
# metric_ripser_sq_sum_H0_norm0.8     0.6815
# metric_ripser_sum_H0_norm0.8        0.6815
# metric_ripser_sq_sum_H0_norm0.95    0.6815
# metric_ripser_sq_sum_H0_norm0.7     0.6811
# metric_ripser_sq_sum_H0_norm0.5     0.6811
# metric_stable_rank                  0.6641
# metric_self_clustering              0.6641
# metric_ripser_sq_sum_H1_norm0.5     0.6560
# metric_ripser_sq_sum_H1_norm0.7     0.6560
# metric_ripser_sq_sum_H1_norm0.8     0.6560
# metric_ripser_sum_H1_norm0.8        0.6377
# metric_coherence                    0.6377
# metric_ripser_sum_H1_norm0.9        0.6377
# metric_ripser_sq_sum_H1_norm0.9     0.6377
# metric_ripser_sq_sum_H1_norm0.95    0.6377
# metric_ripser_sq_sum_H1_norm0.99    0.6377
# metric_ripser_sum_H1_norm0.95       0.6377
# metric_pseudo_condition_number      0.6193
# metric_ripser_sum_H0_norm0.5        0.6081
# metric_rankme                       0.5601
# metric_ripser_sq_sum_H0             0.5601
# metric_ripser_sum_H0                0.5601
# metric_ripser_sq_sum_H1             0.5601
# metric_ripser_sum_H1                0.5601
# ripser_weighted                     0.5601
# Name: auc, dtype: float64

# %%
for param in params_cols:
    corr_df = pd.DataFrame(corr_records[param])
    mean_corr = corr_df[corr_df['sample_fraction'] > 0.0].groupby("metric")["auc"].mean().sort_values(ascending=False)
    print(param)
    print(mean_corr)
# Out:
# batch_size
# metric
# metric_self_clustering              0.76940
# metric_stable_rank                  0.76864
# recall_topk                         0.76810
# metric_ripser_sq_sum_H0             0.73910
# metric_ripser_sum_H0                0.73910
# metric_ripser_sq_sum_H0_norm0.5     0.72278
# metric_rankme                       0.72100
# metric_ripser_sum_H0_norm0.5        0.72008
# metric_ne_sum                       0.71728
# metric_ripser_sum_H0_norm0.7        0.71726
# metric_ripser_sq_sum_H0_norm0.8     0.71726
# metric_ripser_sum_H0_norm0.8        0.71726
# metric_ripser_sq_sum_H0_norm0.7     0.71726
# metric_ripser_sq_sum_H1             0.70934
# metric_ripser_sum_H0_norm0.95       0.70924
# metric_pseudo_condition_number      0.70924
# metric_ripser_sq_sum_H0_norm0.95    0.70924
# ripser_weighted                     0.70822
# metric_ripser_sq_sum_H0_norm0.9     0.70814
# metric_ripser_sum_H0_norm0.9        0.70814
# metric_coherence                    0.70315
# metric_ripser_sum_H1_norm0.99       0.70070
# metric_alpha_req                    0.69968
# metric_ripser_sum_H1                0.69810
# metric_ripser_sum_H0_norm0.99       0.68840
# metric_ripser_sq_sum_H0_norm0.99    0.68770
# metric_ripser_sq_sum_H1_norm0.5     0.60760
# metric_ripser_sum_H1_norm0.7        0.59744
# metric_ripser_sum_H1_norm0.5        0.59744
# metric_ripser_sq_sum_H1_norm0.8     0.59344
# metric_ripser_sum_H1_norm0.95       0.58548
# metric_ripser_sum_H1_norm0.8        0.58548
# metric_ripser_sum_H1_norm0.9        0.58548
# metric_ripser_sq_sum_H1_norm0.7     0.58444
# metric_ripser_sq_sum_H1_norm0.95    0.58444
# metric_ripser_sq_sum_H1_norm0.9     0.58444
# metric_ripser_sq_sum_H1_norm0.99    0.55560
# Name: auc, dtype: float64
# learning_rate
# metric
# metric_ne_sum                       0.75816
# metric_ripser_sum_H0_norm0.9        0.74104
# metric_ripser_sq_sum_H0_norm0.7     0.73964
# metric_ripser_sq_sum_H0_norm0.8     0.73964
# metric_ripser_sq_sum_H0_norm0.9     0.73964
# metric_ripser_sum_H0_norm0.7        0.73964
# metric_ripser_sum_H0_norm0.8        0.73964
# metric_ripser_sum_H0_norm0.95       0.73754
# metric_coherence                    0.73625
# metric_ripser_sq_sum_H0_norm0.95    0.73614
# metric_ripser_sq_sum_H0_norm0.5     0.73380
# metric_ripser_sum_H0_norm0.5        0.73380
# recall_topk                         0.73310
# metric_ripser_sq_sum_H0_norm0.99    0.71604
# metric_ripser_sum_H0_norm0.99       0.71604
# metric_ripser_sq_sum_H1_norm0.9     0.68018
# metric_ripser_sq_sum_H1_norm0.7     0.68018
# metric_ripser_sq_sum_H1_norm0.8     0.68018
# metric_ripser_sq_sum_H1_norm0.5     0.68018
# metric_stable_rank                  0.67510
# metric_rankme                       0.67200
# metric_ripser_sum_H1_norm0.8        0.66606
# metric_ripser_sum_H1_norm0.7        0.66606
# metric_ripser_sum_H1_norm0.95       0.66606
# metric_ripser_sum_H1_norm0.9        0.66606
# metric_ripser_sum_H1_norm0.5        0.66606
# metric_ripser_sq_sum_H1_norm0.95    0.64822
# metric_pseudo_condition_number      0.63478
# metric_ripser_sum_H1_norm0.99       0.59950
# metric_alpha_req                    0.59444
# ripser_weighted                     0.59076
# metric_ripser_sum_H1                0.58708
# metric_ripser_sum_H0                0.58604
# metric_ripser_sq_sum_H0             0.58604
# metric_ripser_sq_sum_H1             0.57980
# metric_self_clustering              0.56860
# metric_ripser_sq_sum_H1_norm0.99    0.55178
# Name: auc, dtype: float64
# split_count
# metric
# metric_ripser_sq_sum_H0_norm0.5     0.77506
# metric_ripser_sum_H0_norm0.5        0.77506
# recall_topk                         0.77010
# metric_ripser_sq_sum_H0_norm0.7     0.75966
# metric_ripser_sum_H0_norm0.7        0.75966
# metric_ripser_sum_H0_norm0.8        0.75852
# metric_ripser_sq_sum_H0_norm0.8     0.75592
# metric_ripser_sum_H0_norm0.95       0.75532
# metric_ripser_sq_sum_H0_norm0.95    0.75532
# metric_coherence                    0.75510
# metric_ripser_sq_sum_H1_norm0.5     0.75404
# metric_ripser_sq_sum_H0_norm0.9     0.75332
# metric_ripser_sum_H0_norm0.9        0.75332
# metric_ne_sum                       0.75154
# metric_ripser_sum_H0_norm0.99       0.75118
# metric_ripser_sq_sum_H0_norm0.99    0.75118
# metric_rankme                       0.73910
# metric_ripser_sum_H0                0.73910
# metric_ripser_sq_sum_H0             0.73910
# metric_self_clustering              0.71630
# metric_stable_rank                  0.71630
# metric_pseudo_condition_number      0.71492
# metric_alpha_req                    0.71080
# ripser_weighted                     0.71006
# metric_ripser_sum_H1_norm0.99       0.70598
# metric_ripser_sum_H1                0.70598
# metric_ripser_sq_sum_H1_norm0.7     0.70544
# metric_ripser_sq_sum_H1             0.70076
# metric_ripser_sq_sum_H1_norm0.9     0.67560
# metric_ripser_sum_H1_norm0.7        0.67560
# metric_ripser_sum_H1_norm0.5        0.67560
# metric_ripser_sq_sum_H1_norm0.8     0.67560
# metric_ripser_sq_sum_H1_norm0.99    0.66214
# metric_ripser_sq_sum_H1_norm0.95    0.66214
# metric_ripser_sum_H1_norm0.8        0.66214
# metric_ripser_sum_H1_norm0.9        0.66214
# metric_ripser_sum_H1_norm0.95       0.64860
# Name: auc, dtype: float64
# cnt_min
# metric
# metric_ripser_sq_sum_H0             0.739100
# metric_ripser_sum_H0                0.739100
# metric_ripser_sum_H0_norm0.5        0.722300
# metric_ripser_sq_sum_H0_norm0.5     0.722300
# metric_ne_sum                       0.720660
# metric_ripser_sq_sum_H0_norm0.7     0.719220
# metric_ripser_sum_H0_norm0.7        0.716140
# ripser_weighted                     0.713900
# metric_ripser_sum_H0_norm0.95       0.709980
# metric_ripser_sum_H0_norm0.8        0.709980
# metric_ripser_sum_H0_norm0.9        0.709980
# metric_ripser_sq_sum_H0_norm0.9     0.709980
# metric_ripser_sq_sum_H0_norm0.95    0.709980
# metric_ripser_sq_sum_H0_norm0.8     0.709980
# metric_ripser_sum_H1                0.709820
# metric_ripser_sum_H1_norm0.99       0.709820
# metric_ripser_sq_sum_H0_norm0.99    0.707520
# metric_ripser_sum_H0_norm0.99       0.707520
# metric_ripser_sq_sum_H1             0.703780
# metric_rankme                       0.700800
# metric_coherence                    0.700525
# metric_pseudo_condition_number      0.697800
# recall_topk                         0.694300
# metric_self_clustering              0.689700
# metric_stable_rank                  0.679800
# metric_alpha_req                    0.595380
# metric_ripser_sq_sum_H1_norm0.95    0.586820
# metric_ripser_sq_sum_H1_norm0.5     0.585380
# metric_ripser_sq_sum_H1_norm0.9     0.579320
# metric_ripser_sum_H1_norm0.7        0.571820
# metric_ripser_sq_sum_H1_norm0.8     0.571820
# metric_ripser_sq_sum_H1_norm0.7     0.571820
# metric_ripser_sum_H1_norm0.5        0.571820
# metric_ripser_sq_sum_H1_norm0.99    0.570780
# metric_ripser_sum_H1_norm0.95       0.569760
# metric_ripser_sum_H1_norm0.8        0.569760
# metric_ripser_sum_H1_norm0.9        0.569760
# Name: auc, dtype: float64
# cnt_max
# metric
# recall_topk                         0.74510
# metric_rankme                       0.73740
# metric_ripser_sum_H0_norm0.5        0.73620
# metric_ne_sum                       0.73504
# metric_ripser_sq_sum_H0_norm0.5     0.73504
# metric_ripser_sum_H0_norm0.8        0.73388
# metric_ripser_sum_H0_norm0.9        0.73388
# metric_ripser_sum_H0_norm0.95       0.73388
# metric_ripser_sq_sum_H0_norm0.8     0.73388
# metric_ripser_sq_sum_H0_norm0.99    0.73388
# metric_ripser_sq_sum_H0_norm0.95    0.73388
# metric_ripser_sq_sum_H0_norm0.9     0.73388
# metric_ripser_sq_sum_H0_norm0.7     0.73388
# metric_ripser_sum_H0_norm0.7        0.73388
# metric_ripser_sum_H0_norm0.99       0.73388
# metric_ripser_sum_H0                0.73300
# metric_ripser_sq_sum_H0             0.73300
# metric_coherence                    0.72285
# metric_self_clustering              0.71860
# metric_stable_rank                  0.71860
# metric_pseudo_condition_number      0.68798
# ripser_weighted                     0.67354
# metric_ripser_sq_sum_H1             0.65680
# metric_ripser_sum_H1                0.64778
# metric_ripser_sum_H1_norm0.99       0.64778
# metric_ripser_sq_sum_H1_norm0.5     0.64494
# metric_ripser_sq_sum_H1_norm0.7     0.62426
# metric_ripser_sq_sum_H1_norm0.8     0.62426
# metric_ripser_sq_sum_H1_norm0.9     0.61226
# metric_ripser_sq_sum_H1_norm0.95    0.61226
# metric_ripser_sum_H1_norm0.8        0.60816
# metric_ripser_sum_H1_norm0.7        0.60816
# metric_ripser_sum_H1_norm0.5        0.60816
# metric_ripser_sum_H1_norm0.9        0.60816
# metric_ripser_sum_H1_norm0.95       0.60816
# metric_ripser_sq_sum_H1_norm0.99    0.58200
# metric_alpha_req                    0.56858
# Name: auc, dtype: float64
# embedding_dim
# metric
# recall_topk                         0.77200
# metric_coherence                    0.76545
# metric_ripser_sq_sum_H0_norm0.9     0.76190
# metric_ripser_sq_sum_H0_norm0.99    0.75944
# metric_ripser_sum_H0_norm0.99       0.75944
# metric_stable_rank                  0.75742
# metric_self_clustering              0.75742
# metric_ripser_sum_H0_norm0.9        0.75584
# metric_ripser_sq_sum_H0_norm0.7     0.75584
# metric_ripser_sum_H0_norm0.7        0.75584
# metric_ripser_sum_H0_norm0.8        0.75584
# metric_ripser_sq_sum_H0_norm0.8     0.75584
# metric_ripser_sq_sum_H0_norm0.95    0.75582
# metric_ne_sum                       0.75286
# metric_rankme                       0.75230
# metric_ripser_sum_H0_norm0.95       0.74556
# metric_ripser_sq_sum_H0_norm0.5     0.74062
# metric_ripser_sum_H0_norm0.5        0.74062
# metric_ripser_sq_sum_H1_norm0.8     0.73620
# metric_ripser_sum_H1_norm0.5        0.73620
# metric_ripser_sq_sum_H1_norm0.5     0.73620
# metric_ripser_sq_sum_H1_norm0.7     0.73620
# metric_ripser_sq_sum_H1_norm0.9     0.73620
# ripser_weighted                     0.72676
# metric_ripser_sq_sum_H0             0.72540
# metric_ripser_sum_H0                0.72540
# metric_ripser_sum_H1                0.72344
# metric_ripser_sq_sum_H1             0.71794
# metric_ripser_sum_H1_norm0.7        0.71404
# metric_ripser_sum_H1_norm0.99       0.71116
# metric_alpha_req                    0.69370
# metric_pseudo_condition_number      0.67404
# metric_ripser_sum_H1_norm0.95       0.62752
# metric_ripser_sum_H1_norm0.8        0.62752
# metric_ripser_sum_H1_norm0.9        0.62752
# metric_ripser_sq_sum_H1_norm0.95    0.62366
# metric_ripser_sq_sum_H1_norm0.99    0.62366
# Name: auc, dtype: float64
# category_embedding_dim
# metric
# recall_topk                         0.71570
# metric_ne_sum                       0.70168
# metric_rankme                       0.70030
# metric_ripser_sq_sum_H0             0.70030
# metric_ripser_sum_H0                0.70030
# metric_coherence                    0.69840
# metric_ripser_sq_sum_H0_norm0.99    0.69562
# metric_ripser_sum_H0_norm0.99       0.69562
# metric_ripser_sq_sum_H1             0.69368
# metric_ripser_sum_H0_norm0.5        0.69340
# metric_ripser_sq_sum_H0_norm0.5     0.69340
# metric_ripser_sum_H0_norm0.95       0.69328
# ripser_weighted                     0.69328
# metric_ripser_sq_sum_H0_norm0.95    0.69328
# metric_ripser_sum_H0_norm0.8        0.69210
# metric_ripser_sq_sum_H0_norm0.8     0.69210
# metric_ripser_sq_sum_H0_norm0.9     0.69094
# metric_ripser_sum_H0_norm0.9        0.69094
# metric_ripser_sum_H1_norm0.99       0.68964
# metric_ripser_sq_sum_H0_norm0.7     0.68860
# metric_ripser_sum_H0_norm0.7        0.68860
# metric_self_clustering              0.68640
# metric_stable_rank                  0.68640
# metric_ripser_sum_H1                0.68560
# metric_pseudo_condition_number      0.68012
# metric_alpha_req                    0.67682
# metric_ripser_sq_sum_H1_norm0.5     0.60752
# metric_ripser_sq_sum_H1_norm0.7     0.60752
# metric_ripser_sq_sum_H1_norm0.9     0.60752
# metric_ripser_sum_H1_norm0.7        0.60752
# metric_ripser_sq_sum_H1_norm0.95    0.60752
# metric_ripser_sq_sum_H1_norm0.8     0.60752
# metric_ripser_sum_H1_norm0.5        0.60752
# metric_ripser_sum_H1_norm0.8        0.60752
# metric_ripser_sum_H1_norm0.95       0.60752
# metric_ripser_sum_H1_norm0.9        0.60752
# metric_ripser_sq_sum_H1_norm0.99    0.59632
# Name: auc, dtype: float64
# hidden_size
# metric
# recall_topk                         0.74770
# metric_ne_sum                       0.74568
# metric_alpha_req                    0.73586
# metric_ripser_sq_sum_H0_norm0.99    0.71038
# metric_ripser_sum_H0_norm0.99       0.70858
# metric_ripser_sum_H1_norm0.99       0.70450
# metric_ripser_sq_sum_H0_norm0.8     0.69302
# metric_ripser_sq_sum_H0_norm0.95    0.69128
# metric_ripser_sq_sum_H0_norm0.9     0.69104
# metric_ripser_sq_sum_H0_norm0.7     0.68960
# metric_ripser_sum_H0_norm0.9        0.68772
# metric_ripser_sum_H0_norm0.8        0.68622
# metric_ripser_sum_H0_norm0.95       0.68432
# metric_ripser_sum_H0_norm0.7        0.68288
# metric_ripser_sq_sum_H0_norm0.5     0.67834
# metric_ripser_sum_H1_norm0.5        0.67524
# metric_ripser_sum_H1_norm0.7        0.66648
# metric_ripser_sq_sum_H1_norm0.5     0.66620
# metric_ripser_sq_sum_H1_norm0.8     0.66620
# metric_ripser_sq_sum_H1_norm0.7     0.66620
# metric_stable_rank                  0.66410
# metric_self_clustering              0.66410
# metric_ripser_sq_sum_H1_norm0.9     0.66254
# metric_ripser_sum_H1_norm0.8        0.65378
# metric_ripser_sq_sum_H1_norm0.99    0.65084
# metric_ripser_sum_H1_norm0.95       0.64646
# metric_ripser_sum_H1_norm0.9        0.64646
# metric_ripser_sq_sum_H1_norm0.95    0.64646
# metric_ripser_sum_H0_norm0.5        0.63390
# metric_pseudo_condition_number      0.62680
# metric_ripser_sum_H1                0.61946
# metric_coherence                    0.61528
# metric_rankme                       0.61342
# metric_ripser_sq_sum_H1             0.56970
# ripser_weighted                     0.56970
# metric_ripser_sum_H0                0.56010
# metric_ripser_sq_sum_H0             0.56010
# Name: auc, dtype: float64
